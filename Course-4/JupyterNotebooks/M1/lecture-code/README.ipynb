# %% [markdown]
# ## Lecture code
#
# This course uses several notebooks to demonstrate key concepts that you need to complete the labs. You will be provided a demo workspace like this per module so you can follow along whenever Sean shows a notebook on screen. To navigate, look at the left sidebar and double-click on the folder that matches the lesson title you're currently on.
#
# <img src='./img/lab_lesson_dirs.png' width=500px>

# %%
! ls /home/jovyan/work/
# Out:
# M1  M2	M3  M4	models	reading  requirements.txt

# %%
! du -sh /home/jovyan/work/
# Out:
# 167G	/home/jovyan/work/

# %%
! tar -zcvf allfiles.tar.gz /home/jovyan/work/M1
# Out:
# tar: Removing leading `/' from member names
# /home/jovyan/work/
# /home/jovyan/work/models/
# /home/jovyan/work/models/qualcomm-c1/
# /home/jovyan/work/models/qualcomm-c1/models/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/RRDB_ESRGAN_x4.pth
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/models/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/models/README.md
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/heads/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/heads/master
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/remotes/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/remotes/origin/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/remotes/origin/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/refs/tags/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/index
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/pre-push.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/pre-merge-commit.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/pre-applypatch.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/applypatch-msg.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/post-update.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/pre-rebase.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/fsmonitor-watchman.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/prepare-commit-msg.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/commit-msg.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/pre-commit.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/push-to-checkout.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/update.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/hooks/pre-receive.sample
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/description
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/info/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/info/exclude
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/objects/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/objects/info/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/objects/pack/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/objects/pack/pack-4d9dccc68475565d8b4770705dcff03fd94293d9.pack
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/objects/pack/pack-4d9dccc68475565d8b4770705dcff03fd94293d9.idx
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/config
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/branches/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/refs/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/refs/heads/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/refs/heads/master
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/refs/remotes/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/refs/remotes/origin/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/refs/remotes/origin/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/logs/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.git/packed-refs
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/transer_RRDB_models.py
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/results/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/results/baboon_ESRGAN.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/.gitignore
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/LR/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/LR/baboon.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/LR/comic.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/QA.md
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/__pycache__/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/__pycache__/RRDBNet_arch.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/RRDBNet_arch.py
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/baboon.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/qualitative_cmp_02.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/patch_b.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/train_deeper_neta.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/architecture.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/qualitative_cmp_04.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/abalation_study.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/43074.gif
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/102061.gif
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/qualitative_cmp_03.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/81.gif
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/train_deeper_netb.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/RRDB.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/patch_a.png
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/qualitative_cmp_01.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/net_interp.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/figures/BN_artifacts.jpg
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/README.md
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/LICENSE
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/test.py
# /home/jovyan/work/models/qualcomm-c1/models/esrgan/v2/xinntao_ESRGAN_git/net_interp.py
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_78s_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_78s_quantized/v1/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_78s_quantized/v1/encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge_quantized/v2/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge_quantized/v2/quicksrnet_large_4x_checkpoint_int8.pth
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge_quantized/v2/aimet_quantization_encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge/v2/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge/v2/quicksrnet_large_4x_checkpoint_float32.pth.tar
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetlarge/v2/quicksrnetlarge_demo.jpg
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall/v2/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall/v2/quicksrnet_small_4x_checkpoint_float32.pth.tar
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_54s_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_54s_quantized/v1/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_54s_quantized/v1/encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5_quantized/v2/
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5_quantized/v2/default_config_per_channel.json
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5_quantized/v2/sesr_m5_4x_checkpoint_int8.pth
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5_quantized/v2/sesr_m5_quantized_encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium/v2/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium/v2/quicksrnet_medium_4x_checkpoint_float32.pth.tar
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall_quantized/v2/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall_quantized/v2/aimet_quantization_encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetsmall_quantized/v2/quicksrnet_small_4x_checkpoint_int8.pth
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5/
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5/v3/
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5/v3/sesr_m5_demo.jpg
# /home/jovyan/work/models/qualcomm-c1/models/sesr_m5/v3/sesr_m5_4x_checkpoint_float32.pth.tar
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium_quantized/v2/
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium_quantized/v2/aimet_quantization_encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/quicksrnetmedium_quantized/v2/quicksrnet_medium_4x_checkpoint_int8.pth
# /home/jovyan/work/models/qualcomm-c1/models/xlsr/
# /home/jovyan/work/models/qualcomm-c1/models/xlsr/v2/
# /home/jovyan/work/models/qualcomm-c1/models/xlsr/v2/xlsr_4x_checkpoint_float32.pth.tar
# /home/jovyan/work/models/qualcomm-c1/models/xlsr/v2/xlsr_demo.jpg
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/scripts/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/scripts/evaluate_cityscapes.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/scripts/evaluate_timing.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/scripts/evaluate_imagenet.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/docker/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/docker/Dockerfile
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/docker/requirements.txt
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/docker/entrypoint.sh
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/model_registry.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/resnet.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/utils.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_N_gpu_large.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_NS_mobile.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_S_gpu_large.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_N_gpu_large.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/utils.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/resnet.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/model_registry.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_S_mobile.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/__init__.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_blocks.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_gpu_large.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_S_gpu_small.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_gpu_small.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_NS_mobile.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__pycache__/ffnet_S_gpu_large.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_gpu_small.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_S_mobile.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/__init__.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_blocks.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_gpu_large.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/models/ffnet_S_gpu_small.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/heads/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/heads/master
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/remotes/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/remotes/origin/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/remotes/origin/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/refs/tags/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/index
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/pre-push.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/pre-merge-commit.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/pre-applypatch.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/applypatch-msg.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/post-update.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/pre-rebase.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/fsmonitor-watchman.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/prepare-commit-msg.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/commit-msg.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/pre-commit.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/push-to-checkout.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/update.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/hooks/pre-receive.sample
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/description
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/info/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/info/exclude
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/objects/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/objects/info/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/objects/pack/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/objects/pack/pack-359e1b5c1c05f0577d904cd819ad755260798609.idx
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/objects/pack/pack-359e1b5c1c05f0577d904cd819ad755260798609.pack
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/config
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/branches/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/refs/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/refs/heads/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/refs/heads/master
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/refs/remotes/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/refs/remotes/origin/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/refs/remotes/origin/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/logs/HEAD
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/.git/packed-refs
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/__pycache__/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/__pycache__/config.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/figures/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/figures/stride_32_gpu_models.png
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/figures/ffnet_architecture.png
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/figures/stem-up-head-choices.png
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/figures/stride_64_gpu_models.png
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/figures/ffnet_3_stage_architecture.png
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/config.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/README.md
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/LICENSE
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/model_weights/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/model_weights/fetch_pre_trained_weights.sh
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/model_weights/README.md
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/.DS_Store
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/cityscapes_labels.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/progress_bar.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/my_data_parallel.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/trnval_utils.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/__pycache__/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/__pycache__/misc.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/__pycache__/__init__.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/attr_dict.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/misc.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/utils/__init__.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/base_loader.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/get_dataloaders.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/transforms.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/__pycache__/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/__pycache__/get_dataloaders.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/__pycache__/transforms.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/__pycache__/base_loader.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/__pycache__/__init__.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/sampler.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/dataloader/__init__.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/__pycache__/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/__pycache__/cityscapes.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/__pycache__/cityscapes_labels.cpython-38.pyc
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/attribution.txt
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/cityscapes/cityscapes.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/imagenet/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/imagenet/imagenet_data_loader.py
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v2/Qualcomm-AI-research_FFNet_git/ffnet_datasets/.DS_Store
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v1/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v1/cityscapes_dummy/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v1/cityscapes_dummy/leftImg8bit/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v1/cityscapes_dummy/leftImg8bit/train/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v1/cityscapes_dummy/leftImg8bit/val/
# /home/jovyan/work/models/qualcomm-c1/models/cityscapes_segmentation/v1/cityscapes_like_demo_2048x1024.jpg
# /home/jovyan/work/models/qualcomm-c1/models/xlsr_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/xlsr_quantized/v2/
# /home/jovyan/work/models/qualcomm-c1/models/xlsr_quantized/v2/default_config_per_channel.json
# /home/jovyan/work/models/qualcomm-c1/models/xlsr_quantized/v2/xlsr_quantized_demo.jpg
# /home/jovyan/work/models/qualcomm-c1/models/xlsr_quantized/v2/aimet_quantization_encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/xlsr_quantized/v2/xlsr_4x_checkpoint_int8.pth
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_40s_quantized/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_40s_quantized/v1/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet_40s_quantized/v1/encodings.json
# /home/jovyan/work/models/qualcomm-c1/models/ffnet/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet/v1/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet/v1/ffnet40S/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet/v1/ffnet40S/ffnet40S_dBBB_cityscapes_state_dict_quarts.pth
# /home/jovyan/work/models/qualcomm-c1/models/ffnet/v1/ffnet122NS/
# /home/jovyan/work/models/qualcomm-c1/models/ffnet/v1/ffnet122NS/ffnet122NS_CCC_cityscapes_state_dict_quarts.pth
# ^C

# %% [markdown]
# <br>
# <br>
#
# Inside, you will see the notebooks and other files needed to run the demos.
#
# <img src='./img/lesson_files.png' width=500px>
#
# Double click on the `.ipynb` file that matches what you see in the lecture. For example, `L1V2_Tour.ipynb` corresponds to the notebook used in the previous video. This will open the notebook in a new tab. From there, you can try running the cells and recreate what you saw in the lecture.

# %% [markdown]
# <br>
# <br>
#
# If you want to go back to the top-level directory, you can click on the folder icon so you can select another folder to work on.
#
# <img src='./img/dir_icon.png' width=500px>
