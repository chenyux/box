# %% [markdown]
# # Food Safety Analysis

# %%
data = {
  "meta": {
    "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
    "terms": "https://open.fda.gov/terms/",
    "license": "https://open.fda.gov/license/",
    "last_updated": "2025-03-05",
    "results": {
      "skip": 0,
      "limit": 1,
      "total": 27084
    }
  },
  "results": [
    {
      "status": "Terminated",
      "city": "Davie",
      "state": "FL",
      "country": "United States",
      "classification": "Class II",
      "openfda": {},
      "product_type": "Food",
      "event_id": "75272",
      "recalling_firm": "Pharmatech LLC",
      "address_1": "4131 SW 47th Ave Ste 1403",
      "address_2": "",
      "postal_code": "33314-4036",
      "voluntary_mandated": "Voluntary: Firm initiated",
      "initial_firm_notification": "Letter",
      "distribution_pattern": "FL, MI, MS, and OH.",
      "recall_number": "F-0276-2017",
      "product_description": "CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.",
      "product_quantity": "1,990 bottles",
      "reason_for_recall": "Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.",
      "recall_initiation_date": "20160808",
      "center_classification_date": "20161025",
      "termination_date": "20240923",
      "report_date": "20161102",
      "code_info": "UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.",
      "more_code_info": ""
    }
  ]
}

# %%
data.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
data["results"]
# Out:
# [{'status': 'Terminated',
#   'city': 'Davie',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '75272',
#   'recalling_firm': 'Pharmatech LLC',
#   'address_1': '4131 SW 47th Ave Ste 1403',
#   'address_2': '',
#   'postal_code': '33314-4036',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'FL, MI, MS, and OH.',
#   'recall_number': 'F-0276-2017',
#   'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#   'product_quantity': '1,990 bottles',
#   'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#   'recall_initiation_date': '20160808',
#   'center_classification_date': '20161025',
#   'termination_date': '20240923',
#   'report_date': '20161102',
#   'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#   'more_code_info': ''}]

# %%
data["results"][0]
# Out:
# {'status': 'Terminated',
#  'city': 'Davie',
#  'state': 'FL',
#  'country': 'United States',
#  'classification': 'Class II',
#  'openfda': {},
#  'product_type': 'Food',
#  'event_id': '75272',
#  'recalling_firm': 'Pharmatech LLC',
#  'address_1': '4131 SW 47th Ave Ste 1403',
#  'address_2': '',
#  'postal_code': '33314-4036',
#  'voluntary_mandated': 'Voluntary: Firm initiated',
#  'initial_firm_notification': 'Letter',
#  'distribution_pattern': 'FL, MI, MS, and OH.',
#  'recall_number': 'F-0276-2017',
#  'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#  'product_quantity': '1,990 bottles',
#  'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#  'recall_initiation_date': '20160808',
#  'center_classification_date': '20161025',
#  'termination_date': '20240923',
#  'report_date': '20161102',
#  'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#  'more_code_info': ''}

# %%
data["results"][0]["product_quantity"]
# Out:
# '1,990 bottles'

# %%
import requests
import pandas as pd

# %%
# Define the URL
url = "https://api.fda.gov/food/enforcement.json" # base endpoint

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2026-06-03',
#   'results': {'skip': 0, 'limit': 1, 'total': 28966}},
#  'results': [{'status': 'Terminated',
#    'city': 'Davie',
#    'state': 'FL',
#    'country': 'United States',
#    'classification': 'Class II',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '75272',
#    'recalling_firm': 'Pharmatech LLC',
#    'address_1': '4131 SW 47th Ave Ste 1403',
#    'address_2': '',
#    'postal_code': '33314-4036',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Letter',
#    'distribution_pattern': 'FL, MI, MS, and OH.',
#    'recall_number': 'F-0276-2017',
#    'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#    'product_quantity': '1,990 bottles',
#    'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#    'recall_initiation_date': '20160808',
#    'center_classification_date': '20161025',
#    'termination_date': '20240923',
#    'report_date': '20161102',
#    'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#    'more_code_info': ''}]}

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 2

# %%
data.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
data["results"]
# Out:
# [{'status': 'Terminated',
#   'city': 'Davie',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '75272',
#   'recalling_firm': 'Pharmatech LLC',
#   'address_1': '4131 SW 47th Ave Ste 1403',
#   'address_2': '',
#   'postal_code': '33314-4036',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'FL, MI, MS, and OH.',
#   'recall_number': 'F-0276-2017',
#   'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#   'product_quantity': '1,990 bottles',
#   'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#   'recall_initiation_date': '20160808',
#   'center_classification_date': '20161025',
#   'termination_date': '20240923',
#   'report_date': '20161102',
#   'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#   'more_code_info': ''}]

# %%
len(data["results"])
# Out:
# 1

# %%
url = "https://api.fda.gov/food/enforcement.json?limit=5"
response = requests.get(url)
data = response.json()

# %%
data["results"]
# Out:
# [{'status': 'Terminated',
#   'city': 'Davie',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '75272',
#   'recalling_firm': 'Pharmatech LLC',
#   'address_1': '4131 SW 47th Ave Ste 1403',
#   'address_2': '',
#   'postal_code': '33314-4036',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'FL, MI, MS, and OH.',
#   'recall_number': 'F-0276-2017',
#   'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#   'product_quantity': '1,990 bottles',
#   'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#   'recall_initiation_date': '20160808',
#   'center_classification_date': '20161025',
#   'termination_date': '20240923',
#   'report_date': '20161102',
#   'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#   'more_code_info': ''},
#  {'country': 'United States',
#   'city': 'Millbrae',
#   'address_1': '375 Adrian Rd',
#   'reason_for_recall': 'Mooncake products, manufactured and distributed by Magic Gourmet Trading, Inc. of Milbrae, CA did not have adequate product labeling, including ingredient statements and allergen declaration. Undeclared ingredients include wheat, peanut oil.',
#   'address_2': '',
#   'product_quantity': '2 cases (1 pc/bx, 48bx/cs)',
#   'code_info': 'FG-M1MOT-UW  Best by Nov 1, 2016.',
#   'center_classification_date': '20170106',
#   'distribution_pattern': 'CA, WA, OR.',
#   'state': 'CA',
#   'product_description': 'Koi Palace Mini Moon Cake: Single Box - Mini Oolong Tea Paste  Unit Size 1/2 lb. and 1/4 lb. in circular box (1 piece) and rectangular boxes (4, 6 or 8 pieces).',
#   'report_date': '20170118',
#   'classification': 'Class II',
#   'openfda': {},
#   'recalling_firm': 'Magic Gourmet Trading Inc',
#   'recall_number': 'F-0865-2017',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '75069',
#   'termination_date': '20170111',
#   'more_code_info': '',
#   'recall_initiation_date': '20160831',
#   'postal_code': '94030-3104',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'status': 'Terminated',
#   'city': 'Miami',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class I',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '69516',
#   'recalling_firm': 'Oasis Brands, Inc',
#   'address_1': '13439 NW 19 LANE',
#   'address_2': 'N/A',
#   'postal_code': '33182',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'FL, GA. NC, and TN',
#   'recall_number': 'F-0609-2015',
#   'product_description': 'Crema GuateLinda (Guatemalan Style Cream) in individually soft poly/plastic bags labeled in part: Lacteos Santa Martha Crema GuateLinda Guatemalan Style Cream Net WT 1 LB (16 oz)',
#   'product_quantity': '144 pieces',
#   'reason_for_recall': 'Virginia State (VDACS) found Listeria monocytogenes in Lacteos Santa Martha Quesito Casero Fresh Curd (Best by 9/27/14), FDA made an inspection, were the environmental samples collected came up positive also for Listeria monocytogenes, also the Oasis Brands Inc. sent finish products samples to a private lab, the Lacteos Santa Martha Cuajada en Hoja Queso Casero Hecho a Mano Fresh Curd (Best By dates of 10/18/14 and 11/25/14) came also positive for Listeria monocytogenes.  Oasis Brands Inc.  is voluntarily recalling ALL their Lacteos Santa Martha brand products manufactured that are within expiration date.',
#   'recall_initiation_date': '20141010',
#   'center_classification_date': '20141202',
#   'termination_date': '20170328',
#   'report_date': '20141210',
#   'code_info': 'UPC 635349 000390  Best By dates: 07/01/14 thru 12/31/14'},
#  {'country': 'United States',
#   'city': 'Pompano Beach',
#   'address_1': '2300 NW 19th St',
#   'reason_for_recall': 'FreshPoint South Florida is recalling sliced fresh yellow onions and salsa products processed using yellow onions sourced from Gills Onions, LLC which were recalled for Listeria monocytogenes.',
#   'address_2': '',
#   'product_quantity': '7 cases',
#   'code_info': 'Item #   302940.',
#   'center_classification_date': '20120808',
#   'distribution_pattern': 'Products were distributed in South Florida.',
#   'state': 'FL',
#   'product_description': 'Yellow Onion.  Product is labeled in part:  "***FC Salsa Mango"***Refrigerate at 34 F***"      Item #   302940 FC SALSA MANGO 2/5#.        Product is fresh made - Ready To Eat.',
#   'report_date': '20120815',
#   'classification': 'Class I',
#   'openfda': {},
#   'recalling_firm': 'FreshPoint South Florida',
#   'recall_number': 'F-1922-2012',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'product_type': 'Food',
#   'event_id': '62750',
#   'termination_date': '20141008',
#   'more_code_info': '',
#   'recall_initiation_date': '20120727',
#   'postal_code': '33069-5227',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'status': 'Terminated'},
#  {'status': 'Terminated',
#   'city': 'Rancho Dominguez',
#   'state': 'CA',
#   'country': 'United States',
#   'classification': 'Class III',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '85253',
#   'recalling_firm': 'Organic By Nature, Inc.',
#   'address_1': '2610 Homestead Pl',
#   'address_2': 'N/A',
#   'postal_code': '90220-5610',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#   'distribution_pattern': 'nationwide, Canada and Netherlands',
#   'recall_number': 'F-0904-2020',
#   'product_description': 'Pure Planet Organic Parasite Cleanse;  Net Wt. 174g Glass Jar;  Finished Product Item # 52700    Manufactured and Distributed by:  Pure Planet,  Rancho Dominguez, CA',
#   'product_quantity': 'xx',
#   'reason_for_recall': 'Firm was notified by supplier that Organic Ground Flaxseed powder was under recall by manufacturer due to unapproved herbicide - Haloxyfop',
#   'recall_initiation_date': '20200224',
#   'center_classification_date': '20200413',
#   'termination_date': '20210202',
#   'report_date': '20200401',
#   'code_info': 'Lot codes: 72746',
#   'more_code_info': ''}]

# %%
len(data["results"])
# Out:
# 5

# %%
url = "https://api.fda.gov/food/enforcement.json?search=state:HI"
response = requests.get(url)
data = response.json()

# %%
data["results"][0]
# Out:
# {'country': 'United States',
#  'city': 'Kapaa',
#  'address_1': '5915 Olohena Rd',
#  'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#  'address_2': 'Unit H',
#  'product_quantity': 'All',
#  'code_info': 'UPC for single truffles: 11386711886    No lot codes or expiry dates',
#  'center_classification_date': '20140825',
#  'distribution_pattern': 'HI only',
#  'state': 'HI',
#  'product_description': 'Tiny Isle Chocolate Truffles Macadamia Nut: Gluten Free, Raw, Vegan; individual 1 oz. candies,    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#  'report_date': '20140903',
#  'classification': 'Class I',
#  'openfda': {},
#  'recalling_firm': 'Florimont, Inc.',
#  'recall_number': 'F-2387-2014',
#  'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#  'product_type': 'Food',
#  'event_id': '68994',
#  'termination_date': '20141104',
#  'recall_initiation_date': '20140725',
#  'postal_code': '96746-7709',
#  'voluntary_mandated': 'Voluntary: Firm initiated',
#  'status': 'Terminated'}

# %%
params = {
    "limit": 5
}
response = requests.get(url, params=params)
data = response.json()

# %%
data
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2026-06-03',
#   'results': {'skip': 0, 'limit': 5, 'total': 70}},
#  'results': [{'country': 'United States',
#    'city': 'Kapaa',
#    'address_1': '5915 Olohena Rd',
#    'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#    'address_2': 'Unit H',
#    'product_quantity': 'All',
#    'code_info': 'UPC for single truffles: 11386711886    No lot codes or expiry dates',
#    'center_classification_date': '20140825',
#    'distribution_pattern': 'HI only',
#    'state': 'HI',
#    'product_description': 'Tiny Isle Chocolate Truffles Macadamia Nut: Gluten Free, Raw, Vegan; individual 1 oz. candies,    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#    'report_date': '20140903',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Florimont, Inc.',
#    'recall_number': 'F-2387-2014',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '68994',
#    'termination_date': '20141104',
#    'recall_initiation_date': '20140725',
#    'postal_code': '96746-7709',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'status': 'Terminated',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'country': 'United States',
#    'classification': 'Class II',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '82877',
#    'recalling_firm': 'Regal Food Inc./dba The Pizza Shop',
#    'address_1': '3040 Ualena St',
#    'address_2': 'N/A',
#    'postal_code': '96819-1984',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Letter',
#    'distribution_pattern': 'HI only - island of Oahu',
#    'recall_number': 'F-1459-2019',
#    'product_description': "Regal's Fundraising Cookies: Cornflake flavor.  Net Weight 12 oz. (340 grams).    All varieties have the same ingredient list:  Flour, Sugar, Cotton Seed Oil, Butter Blend, Chocolate Chips, Salted Butter, Vanilla Extract, Salt, Baking Soda.    Regal Foods,  Honolulu, HI  www.regalfoodsusa.com",
#    'product_quantity': 'N/A',
#    'reason_for_recall': 'FDA inspection found that allergen sub ingredients are not declared on the label - wheat, soy, milk.',
#    'recall_initiation_date': '20190515',
#    'center_classification_date': '20190614',
#    'termination_date': '20191119',
#    'report_date': '20190626',
#    'code_info': 'all manufacturing codes - i.e.05/02/19'},
#   {'country': 'United States',
#    'city': 'Kapaa',
#    'address_1': '5915 Olohena Rd',
#    'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#    'address_2': 'Unit H',
#    'product_quantity': 'All',
#    'code_info': 'UPC for single truffles: 11386711886    No lot codes or expiry dates',
#    'center_classification_date': '20140825',
#    'distribution_pattern': 'HI only',
#    'state': 'HI',
#    'product_description': 'Tiny Isle Chocolate Truffles Spicy Lava: Gluten Free, Raw, Vegan; individual 1 oz. candies,    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#    'report_date': '20140903',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Florimont, Inc.',
#    'recall_number': 'F-2386-2014',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '68994',
#    'termination_date': '20141104',
#    'recall_initiation_date': '20140725',
#    'postal_code': '96746-7709',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'country': 'United States',
#    'city': 'Kapaa',
#    'address_1': '5915 Olohena Rd',
#    'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#    'address_2': 'Unit H',
#    'product_quantity': 'ALL',
#    'code_info': 'UPC 011386071157No lot codes or expiry dates',
#    'center_classification_date': '20140825',
#    'distribution_pattern': 'HI only',
#    'state': 'HI',
#    'product_description': 'Tiny Isle Original Fudge, 2 oz.; Organic-Raw- Gluten Free;  Ingredients: Cacao powder, coconut oil. agave nectar, carob powder, vanilla, sea salt.  Keep cold.    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#    'report_date': '20140903',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Florimont, Inc.',
#    'recall_number': 'F-2380-2014',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '68994',
#    'termination_date': '20141104',
#    'recall_initiation_date': '20140725',
#    'postal_code': '96746-7709',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'status': 'Terminated',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'country': 'United States',
#    'classification': 'Class III',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '68673',
#    'recalling_firm': 'Modern Macaroni Co Ltd',
#    'address_1': '1708 Mary St',
#    'address_2': '',
#    'postal_code': '96819-3103',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'distribution_pattern': 'HI and one location in San Francisco',
#    'recall_number': 'F-2089-2014',
#    'product_description': 'Hula Brand Products; Hana Ebi Red; artificially colored shrimp flakes);  Packed in 1 lb. (545 g) and 6 oz. packages.  Servins size 2 pinches (1 g)    Manufactured by Modern Macaroni Co., Honolulu, HI  Serving size is "2" pinches',
#    'product_quantity': 'unknown',
#    'reason_for_recall': 'FDA sample 466576 found 208.46 ppm of Sulfites in Hana Ebi dried shrimp product.',
#    'recall_initiation_date': '20140620',
#    'center_classification_date': '20140709',
#    'termination_date': '20150226',
#    'report_date': '20140716',
#    'code_info': 'Red - 1 lb UPC 73366-22044;  Red - 0.6 oz. UPD 73366-22042;  Green - i lb. - UPC 73366-22045;  Green - 0.6 oz. UPC 73366-22043.  No other code numbers',
#    'more_code_info': ''}]}

# %%
url = "https://api.fda.gov/food/enforcement.json"
params = {
    "limit": 1000
}

data = requests.get(url, params=params).json()

# %%
data.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
df = pd.DataFrame(data["results"])

# %%
len(df)
# Out:
# 1000

# %%
df.columns
# Out:
# Index(['status', 'city', 'state', 'country', 'classification', 'openfda',
#        'product_type', 'event_id', 'recalling_firm', 'address_1', 'address_2',
#        'postal_code', 'voluntary_mandated', 'initial_firm_notification',
#        'distribution_pattern', 'recall_number', 'product_description',
#        'product_quantity', 'reason_for_recall', 'recall_initiation_date',
#        'center_classification_date', 'termination_date', 'report_date',
#        'code_info', 'more_code_info'],
#       dtype='object')

# %%
data["results"][0].keys()
# Out:
# dict_keys(['status', 'city', 'state', 'country', 'classification', 'openfda', 'product_type', 'event_id', 'recalling_firm', 'address_1', 'address_2', 'postal_code', 'voluntary_mandated', 'initial_firm_notification', 'distribution_pattern', 'recall_number', 'product_description', 'product_quantity', 'reason_for_recall', 'recall_initiation_date', 'center_classification_date', 'termination_date', 'report_date', 'code_info', 'more_code_info'])

# %%
data["results"][1].keys()
# Out:
# dict_keys(['country', 'city', 'address_1', 'reason_for_recall', 'address_2', 'product_quantity', 'code_info', 'center_classification_date', 'distribution_pattern', 'state', 'product_description', 'report_date', 'classification', 'openfda', 'recalling_firm', 'recall_number', 'initial_firm_notification', 'product_type', 'event_id', 'termination_date', 'more_code_info', 'recall_initiation_date', 'postal_code', 'voluntary_mandated', 'status'])

# %%
df.dtypes
# Out:
# status                        object
# city                          object
# state                         object
# country                       object
# classification                object
# openfda                       object
# product_type                  object
# event_id                      object
# recalling_firm                object
# address_1                     object
# address_2                     object
# postal_code                   object
# voluntary_mandated            object
# initial_firm_notification     object
# distribution_pattern          object
# recall_number                 object
# product_description           object
# product_quantity              object
# reason_for_recall             object
# recall_initiation_date        object
# center_classification_date    object
# termination_date              object
# report_date                   object
# code_info                     object
# more_code_info                object
# dtype: object

# %%
df.head()
# Out:
#        status              city state        country classification openfda  \
# 0  Terminated             Davie    FL  United States       Class II      {}
# 1  Terminated          Millbrae    CA  United States       Class II      {}
# 2  Terminated             Miami    FL  United States        Class I      {}
# 3  Terminated     Pompano Beach    FL  United States        Class I      {}
# 4  Terminated  Rancho Dominguez    CA  United States      Class III      {}
#
#   product_type event_id             recalling_firm                  address_1  \
# 0         Food    75272             Pharmatech LLC  4131 SW 47th Ave Ste 1403
# 1         Food    75069  Magic Gourmet Trading Inc              375 Adrian Rd
# 2         Food    69516          Oasis Brands, Inc           13439 NW 19 LANE
# 3         Food    62750   FreshPoint South Florida            2300 NW 19th St
# 4         Food    85253    Organic By Nature, Inc.          2610 Homestead Pl
#
#    ... recall_number                                product_description  \
# 0  ...   F-0276-2017  CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1  ...   F-0865-2017  Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2  ...   F-0609-2015  Crema GuateLinda (Guatemalan Style Cream) in i...
# 3  ...   F-1922-2012  Yellow Onion.  Product is labeled in part:  "*...
# 4  ...   F-0904-2020  Pure Planet Organic Parasite Cleanse;  Net Wt....
#
#              product_quantity  \
# 0               1,990 bottles
# 1  2 cases (1 pc/bx, 48bx/cs)
# 2                  144 pieces
# 3                     7 cases
# 4                          xx
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...               20160808
# 1  Mooncake products, manufactured and distribute...               20160831
# 2  Virginia State (VDACS) found Listeria monocyto...               20141010
# 3  FreshPoint South Florida is recalling sliced f...               20120727
# 4  Firm was notified by supplier that Organic Gro...               20200224
#
#   center_classification_date termination_date report_date  \
# 0                   20161025         20240923    20161102
# 1                   20170106         20170111    20170118
# 2                   20141202         20170328    20141210
# 3                   20120808         20141008    20120815
# 4                   20200413         20210202    20200401
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
# 1                  FG-M1MOT-UW  Best by Nov 1, 2016.
# 2  UPC 635349 000390  Best By dates: 07/01/14 thr...            NaN
# 3                                   Item #   302940.
# 4                                   Lot codes: 72746
#
# [5 rows x 25 columns]

# %%
df["recall_initiation_date"] = pd.to_datetime(df["recall_initiation_date"])
df["center_classification_date"] = pd.to_datetime(df["center_classification_date"])
df["termination_date"] = pd.to_datetime(df["termination_date"])
df["report_date"] = pd.to_datetime(df["report_date"])

# %%
df.head()
# Out:
#        status              city state        country classification openfda  \
# 0  Terminated             Davie    FL  United States       Class II      {}
# 1  Terminated          Millbrae    CA  United States       Class II      {}
# 2  Terminated             Miami    FL  United States        Class I      {}
# 3  Terminated     Pompano Beach    FL  United States        Class I      {}
# 4  Terminated  Rancho Dominguez    CA  United States      Class III      {}
#
#   product_type event_id             recalling_firm                  address_1  \
# 0         Food    75272             Pharmatech LLC  4131 SW 47th Ave Ste 1403
# 1         Food    75069  Magic Gourmet Trading Inc              375 Adrian Rd
# 2         Food    69516          Oasis Brands, Inc           13439 NW 19 LANE
# 3         Food    62750   FreshPoint South Florida            2300 NW 19th St
# 4         Food    85253    Organic By Nature, Inc.          2610 Homestead Pl
#
#    ... recall_number                                product_description  \
# 0  ...   F-0276-2017  CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1  ...   F-0865-2017  Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2  ...   F-0609-2015  Crema GuateLinda (Guatemalan Style Cream) in i...
# 3  ...   F-1922-2012  Yellow Onion.  Product is labeled in part:  "*...
# 4  ...   F-0904-2020  Pure Planet Organic Parasite Cleanse;  Net Wt....
#
#              product_quantity  \
# 0               1,990 bottles
# 1  2 cases (1 pc/bx, 48bx/cs)
# 2                  144 pieces
# 3                     7 cases
# 4                          xx
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...             2016-08-08
# 1  Mooncake products, manufactured and distribute...             2016-08-31
# 2  Virginia State (VDACS) found Listeria monocyto...             2014-10-10
# 3  FreshPoint South Florida is recalling sliced f...             2012-07-27
# 4  Firm was notified by supplier that Organic Gro...             2020-02-24
#
#   center_classification_date termination_date report_date  \
# 0                 2016-10-25       2024-09-23  2016-11-02
# 1                 2017-01-06       2017-01-11  2017-01-18
# 2                 2014-12-02       2017-03-28  2014-12-10
# 3                 2012-08-08       2014-10-08  2012-08-15
# 4                 2020-04-13       2021-02-02  2020-04-01
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
# 1                  FG-M1MOT-UW  Best by Nov 1, 2016.
# 2  UPC 635349 000390  Best By dates: 07/01/14 thr...            NaN
# 3                                   Item #   302940.
# 4                                   Lot codes: 72746
#
# [5 rows x 25 columns]

# %%
pd.unique(df["classification"])
# Out:
# array(['Class II', 'Class I', 'Class III'], dtype=object)

# %%
# df["classification"] = df["classification"].str.replace("Class I", "1")
# df["classification"] = df["classification"].str.replace("Class II", "2")
# df["classification"] = df["classification"].str.replace("Class III", "3")

# %%
pd.unique(df["classification"])
# Out:
# array(['Class II', 'Class I', 'Class III'], dtype=object)

# %%
df["classification"] = df["classification"].map({
    "Class I": "1",
    "Class II": "2",
    "Class III": "3"
})

# %%
df.head()
# Out:
#        status              city state        country classification openfda  \
# 0  Terminated             Davie    FL  United States              2      {}
# 1  Terminated          Millbrae    CA  United States              2      {}
# 2  Terminated             Miami    FL  United States              1      {}
# 3  Terminated     Pompano Beach    FL  United States              1      {}
# 4  Terminated  Rancho Dominguez    CA  United States              3      {}
#
#   product_type event_id             recalling_firm                  address_1  \
# 0         Food    75272             Pharmatech LLC  4131 SW 47th Ave Ste 1403
# 1         Food    75069  Magic Gourmet Trading Inc              375 Adrian Rd
# 2         Food    69516          Oasis Brands, Inc           13439 NW 19 LANE
# 3         Food    62750   FreshPoint South Florida            2300 NW 19th St
# 4         Food    85253    Organic By Nature, Inc.          2610 Homestead Pl
#
#    ... recall_number                                product_description  \
# 0  ...   F-0276-2017  CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1  ...   F-0865-2017  Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2  ...   F-0609-2015  Crema GuateLinda (Guatemalan Style Cream) in i...
# 3  ...   F-1922-2012  Yellow Onion.  Product is labeled in part:  "*...
# 4  ...   F-0904-2020  Pure Planet Organic Parasite Cleanse;  Net Wt....
#
#              product_quantity  \
# 0               1,990 bottles
# 1  2 cases (1 pc/bx, 48bx/cs)
# 2                  144 pieces
# 3                     7 cases
# 4                          xx
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...             2016-08-08
# 1  Mooncake products, manufactured and distribute...             2016-08-31
# 2  Virginia State (VDACS) found Listeria monocyto...             2014-10-10
# 3  FreshPoint South Florida is recalling sliced f...             2012-07-27
# 4  Firm was notified by supplier that Organic Gro...             2020-02-24
#
#   center_classification_date termination_date report_date  \
# 0                 2016-10-25       2024-09-23  2016-11-02
# 1                 2017-01-06       2017-01-11  2017-01-18
# 2                 2014-12-02       2017-03-28  2014-12-10
# 3                 2012-08-08       2014-10-08  2012-08-15
# 4                 2020-04-13       2021-02-02  2020-04-01
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
# 1                  FG-M1MOT-UW  Best by Nov 1, 2016.
# 2  UPC 635349 000390  Best By dates: 07/01/14 thr...            NaN
# 3                                   Item #   302940.
# 4                                   Lot codes: 72746
#
# [5 rows x 25 columns]

# %%
df["classification"] = df["classification"].astype("Int64")

# %%
df.dtypes
# Out:
# status                                object
# city                                  object
# state                                 object
# country                               object
# classification                         Int64
# openfda                               object
# product_type                          object
# event_id                              object
# recalling_firm                        object
# address_1                             object
# address_2                             object
# postal_code                           object
# voluntary_mandated                    object
# initial_firm_notification             object
# distribution_pattern                  object
# recall_number                         object
# product_description                   object
# product_quantity                      object
# reason_for_recall                     object
# recall_initiation_date        datetime64[ns]
# center_classification_date    datetime64[ns]
# termination_date              datetime64[ns]
# report_date                   datetime64[ns]
# code_info                             object
# more_code_info                        object
# dtype: object

# %%
url = "https://api.fda.gov/food/enforcement.json"

# %%
dfs = [] # collects dataframes

# Iterating over the range to fetch 25,000 records in batches of 1,000
for i in range(25):
    params = {
        "limit": 1000,
        "skip": i * 1000
    }

    # Fetching data from the API
    data = requests.get(url, params=params).json()

    # Append dataframe of 1000 rows to list of dfs
    dfs.append(pd.DataFrame(data["results"])) 

    print("i=", i)

# Combine dataframes
df = pd.concat(dfs, ignore_index=True)
# Out:
# i= 0
# i= 1
# i= 2
# i= 3
# i= 4
# i= 5
# i= 6
# i= 7
# i= 8
# i= 9
# i= 10
# i= 11
# i= 12
# i= 13
# i= 14
# i= 15
# i= 16
# i= 17
# i= 18
# i= 19
# i= 20
# i= 21
# i= 22
# i= 23
# i= 24

# %%
len(df)
# Out:
# 25000

# %%
df.head()
# Out:
#        status              city state        country classification openfda  \
# 0  Terminated             Davie    FL  United States       Class II      {}
# 1  Terminated          Millbrae    CA  United States       Class II      {}
# 2  Terminated             Miami    FL  United States        Class I      {}
# 3  Terminated     Pompano Beach    FL  United States        Class I      {}
# 4  Terminated  Rancho Dominguez    CA  United States      Class III      {}
#
#   product_type event_id             recalling_firm                  address_1  \
# 0         Food    75272             Pharmatech LLC  4131 SW 47th Ave Ste 1403
# 1         Food    75069  Magic Gourmet Trading Inc              375 Adrian Rd
# 2         Food    69516          Oasis Brands, Inc           13439 NW 19 LANE
# 3         Food    62750   FreshPoint South Florida            2300 NW 19th St
# 4         Food    85253    Organic By Nature, Inc.          2610 Homestead Pl
#
#    ... recall_number                                product_description  \
# 0  ...   F-0276-2017  CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1  ...   F-0865-2017  Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2  ...   F-0609-2015  Crema GuateLinda (Guatemalan Style Cream) in i...
# 3  ...   F-1922-2012  Yellow Onion.  Product is labeled in part:  "*...
# 4  ...   F-0904-2020  Pure Planet Organic Parasite Cleanse;  Net Wt....
#
#              product_quantity  \
# 0               1,990 bottles
# 1  2 cases (1 pc/bx, 48bx/cs)
# 2                  144 pieces
# 3                     7 cases
# 4                          xx
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...               20160808
# 1  Mooncake products, manufactured and distribute...               20160831
# 2  Virginia State (VDACS) found Listeria monocyto...               20141010
# 3  FreshPoint South Florida is recalling sliced f...               20120727
# 4  Firm was notified by supplier that Organic Gro...               20200224
#
#   center_classification_date termination_date report_date  \
# 0                   20161025         20240923    20161102
# 1                   20170106         20170111    20170118
# 2                   20141202         20170328    20141210
# 3                   20120808         20141008    20120815
# 4                   20200413         20210202    20200401
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
# 1                  FG-M1MOT-UW  Best by Nov 1, 2016.
# 2  UPC 635349 000390  Best By dates: 07/01/14 thr...            NaN
# 3                                   Item #   302940.
# 4                                   Lot codes: 72746
#
# [5 rows x 25 columns]

# %%
df["classification"] = df["classification"].replace({
    "Class I": "1",
    "Class II": "2",
    "Class III": "3"
})
df["classification"] = df["classification"].astype("Int64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 6
#       1 df["classification"] = df["classification"].replace({
#       2     "Class I": "1",
#       3     "Class II": "2",
#       4     "Class III": "3"
#       5 })
# ----> 6 df["classification"] = df["classification"].astype("Int64")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:80, in _astype_nansafe(arr, dtype, copy, skipna)
#      78 # dispatch on extension dtype if needed
#      79 if isinstance(dtype, ExtensionDtype):
# ---> 80     return dtype.construct_array_type()._from_sequence(arr, dtype=dtype, copy=copy)
#      82 elif not isinstance(dtype, np.dtype):  # pragma: no cover
#      83     raise ValueError("dtype must be np.dtype or ExtensionDtype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:152, in BaseMaskedArray._from_sequence(cls, scalars, dtype, copy)
#     150 @classmethod
#     151 def _from_sequence(cls, scalars, *, dtype=None, copy: bool = False) -> Self:
# --> 152     values, mask = cls._coerce_to_array(scalars, dtype=dtype, copy=copy)
#     153     return cls(values, mask)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\numeric.py:272, in NumericArray._coerce_to_array(cls, value, dtype, copy)
#     270 dtype_cls = cls._dtype_cls
#     271 default_dtype = dtype_cls._default_np_dtype
# --> 272 values, mask, _, _ = _coerce_to_data_and_mask(
#     273     value, dtype, copy, dtype_cls, default_dtype
#     274 )
#     275 return values, mask
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\numeric.py:227, in _coerce_to_data_and_mask(values, dtype, copy, dtype_cls, default_dtype)
#     223     values[mask] = cls._internal_fill_value
#     224 if inferred_type in ("string", "unicode"):
#     225     # casts from str are always safe since they raise
#     226     # a ValueError if the str cannot be parsed into a float
# --> 227     values = values.astype(dtype, copy=copy)
#     228 else:
#     229     values = dtype_cls._safe_cast(values, dtype, copy=False)
#
# ValueError: invalid literal for int() with base 10: 'Not Yet Classified'

# %%
df[df["classification"] == "Not Yet Classified"]
# Out:
#        status       city state        country      classification openfda  \
# 7087  Ongoing  Lancaster    VA  United States  Not Yet Classified      {}
#
#      product_type event_id    recalling_firm               address_1  ...  \
# 7087         Food    94636  BooKoo Foods LLC  1890 White Chapel Road  ...
#
#      recall_number                                product_description  \
# 7087                Abundant Life Foods brand Gluten Free Chocolat...
#
#      product_quantity  reason_for_recall recall_initiation_date  \
# 7087  10 cases/60 lbs  Undeclared gluten               20240513
#
#      center_classification_date termination_date report_date  \
# 7087                        NaN              NaN    20240605
#
#                         code_info more_code_info
# 7087  Manufacture/Lot: 04/30/2024
#
# [1 rows x 25 columns]

# %%
df.loc[7087, "classification"] = "3"

# %%
df.loc[7087]
# Out:
# status                                                                  Ongoing
# city                                                                  Lancaster
# state                                                                        VA
# country                                                           United States
# classification                                                                3
# openfda                                                                      {}
# product_type                                                               Food
# event_id                                                                  94636
# recalling_firm                                                 BooKoo Foods LLC
# address_1                                                1890 White Chapel Road
# address_2
# postal_code                                                               22503
# voluntary_mandated                                    Voluntary: Firm initiated
# initial_firm_notification     Two or more of the following: Email, Fax, Lett...
# distribution_pattern          Distributed to a distribution center in Minnes...
# recall_number
# product_description           Abundant Life Foods brand Gluten Free Chocolat...
# product_quantity                                                10 cases/60 lbs
# reason_for_recall                                             Undeclared gluten
# recall_initiation_date                                      2024-05-13 00:00:00
# center_classification_date                                                  NaT
# termination_date                                                            NaT
# report_date                                                 2024-06-05 00:00:00
# code_info                                           Manufacture/Lot: 04/30/2024
# more_code_info
# Name: 7087, dtype: object

# %%
df["recall_initiation_date"] = pd.to_datetime(df["recall_initiation_date"])
df["center_classification_date"] = pd.to_datetime(df["center_classification_date"])
df["termination_date"] = pd.to_datetime(df["termination_date"])
df["report_date"] = pd.to_datetime(df["report_date"])

# %%
df["recall_initiation_date"].sort_values()
# Out:
# 10921   2008-06-07
# 8255    2008-06-07
# 1734    2008-06-07
# 8583    2008-06-09
# 18492   2008-07-07
#            ...
# 15088   2026-05-05
# 14577   2026-05-05
# 3559    2026-05-05
# 16257   2026-05-07
# 23709   2026-05-08
# Name: recall_initiation_date, Length: 25000, dtype: datetime64[ns]

# %%
# the index is different from the recording. this code will fetch the right value.
first_index = df["recall_initiation_date"].sort_values().index[0]

df.at[first_index, 'recall_initiation_date'] = 20121207

# %%
df["recall_initiation_date"] = pd.to_datetime(df["recall_initiation_date"])
df["center_classification_date"] = pd.to_datetime(df["center_classification_date"])
df["termination_date"] = pd.to_datetime(df["termination_date"])
df["report_date"] = pd.to_datetime(df["report_date"])

# %%
df.dtypes
# Out:
# status                                object
# city                                  object
# state                                 object
# country                               object
# classification                        object
# openfda                               object
# product_type                          object
# event_id                              object
# recalling_firm                        object
# address_1                             object
# address_2                             object
# postal_code                           object
# voluntary_mandated                    object
# initial_firm_notification             object
# distribution_pattern                  object
# recall_number                         object
# product_description                   object
# product_quantity                      object
# reason_for_recall                     object
# recall_initiation_date        datetime64[ns]
# center_classification_date    datetime64[ns]
# termination_date              datetime64[ns]
# report_date                   datetime64[ns]
# code_info                             object
# more_code_info                        object
# dtype: object

# %%
df["duration"] = df["termination_date"] - df["recall_initiation_date"]

# %%
df.head()
# Out:
#        status              city state        country classification openfda  \
# 0  Terminated             Davie    FL  United States              2      {}
# 1  Terminated          Millbrae    CA  United States              2      {}
# 2  Terminated             Miami    FL  United States              1      {}
# 3  Terminated     Pompano Beach    FL  United States              1      {}
# 4  Terminated  Rancho Dominguez    CA  United States              3      {}
#
#   product_type event_id             recalling_firm                  address_1  \
# 0         Food    75272             Pharmatech LLC  4131 SW 47th Ave Ste 1403
# 1         Food    75069  Magic Gourmet Trading Inc              375 Adrian Rd
# 2         Food    69516          Oasis Brands, Inc           13439 NW 19 LANE
# 3         Food    62750   FreshPoint South Florida            2300 NW 19th St
# 4         Food    85253    Organic By Nature, Inc.          2610 Homestead Pl
#
#    ...                                product_description  \
# 0  ...  CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1  ...  Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2  ...  Crema GuateLinda (Guatemalan Style Cream) in i...
# 3  ...  Yellow Onion.  Product is labeled in part:  "*...
# 4  ...  Pure Planet Organic Parasite Cleanse;  Net Wt....
#
#              product_quantity  \
# 0               1,990 bottles
# 1  2 cases (1 pc/bx, 48bx/cs)
# 2                  144 pieces
# 3                     7 cases
# 4                          xx
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...             2016-08-08
# 1  Mooncake products, manufactured and distribute...             2016-08-31
# 2  Virginia State (VDACS) found Listeria monocyto...             2014-10-10
# 3  FreshPoint South Florida is recalling sliced f...             2012-07-27
# 4  Firm was notified by supplier that Organic Gro...             2020-02-24
#
#   center_classification_date termination_date report_date  \
# 0                 2016-10-25       2024-09-23  2016-11-02
# 1                 2017-01-06       2017-01-11  2017-01-18
# 2                 2014-12-02       2017-03-28  2014-12-10
# 3                 2012-08-08       2014-10-08  2012-08-15
# 4                 2020-04-13       2021-02-02  2020-04-01
#
#                                            code_info more_code_info  duration
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...                2968 days
# 1                  FG-M1MOT-UW  Best by Nov 1, 2016.                 133 days
# 2  UPC 635349 000390  Best By dates: 07/01/14 thr...            NaN  900 days
# 3                                   Item #   302940.                 803 days
# 4                                   Lot codes: 72746                 344 days
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   status                      25000 non-null  object
#  1   city                        25000 non-null  object
#  2   state                       25000 non-null  object
#  3   country                     25000 non-null  object
#  4   classification              25000 non-null  object
#  5   openfda                     25000 non-null  object
#  6   product_type                25000 non-null  object
#  7   event_id                    25000 non-null  object
#  8   recalling_firm              25000 non-null  object
#  9   address_1                   25000 non-null  object
#  10  address_2                   25000 non-null  object
#  11  postal_code                 25000 non-null  object
#  12  voluntary_mandated          25000 non-null  object
#  13  initial_firm_notification   25000 non-null  object
#  14  distribution_pattern        25000 non-null  object
#  15  recall_number               25000 non-null  object
#  16  product_description         25000 non-null  object
#  17  product_quantity            25000 non-null  object
#  18  reason_for_recall           25000 non-null  object
#  19  recall_initiation_date      25000 non-null  datetime64[ns]
#  20  center_classification_date  24998 non-null  datetime64[ns]
#  21  termination_date            23764 non-null  datetime64[ns]
#  22  report_date                 25000 non-null  datetime64[ns]
#  23  code_info                   25000 non-null  object
#  24  more_code_info              10915 non-null  object
#  25  duration                    23764 non-null  timedelta64[ns]
# dtypes: datetime64[ns](4), object(21), timedelta64[ns](1)
# memory usage: 5.0+ MB

# %%
pd.unique(df["status"])
# Out:
# array(['Terminated', 'Ongoing', 'Completed'], dtype=object)

# %%
duration_df = df.dropna(subset=["duration"])

# %%
duration_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23764 entries, 0 to 24999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   status                      23764 non-null  object
#  1   city                        23764 non-null  object
#  2   state                       23764 non-null  object
#  3   country                     23764 non-null  object
#  4   classification              23764 non-null  object
#  5   openfda                     23764 non-null  object
#  6   product_type                23764 non-null  object
#  7   event_id                    23764 non-null  object
#  8   recalling_firm              23764 non-null  object
#  9   address_1                   23764 non-null  object
#  10  address_2                   23764 non-null  object
#  11  postal_code                 23764 non-null  object
#  12  voluntary_mandated          23764 non-null  object
#  13  initial_firm_notification   23764 non-null  object
#  14  distribution_pattern        23764 non-null  object
#  15  recall_number               23764 non-null  object
#  16  product_description         23764 non-null  object
#  17  product_quantity            23764 non-null  object
#  18  reason_for_recall           23764 non-null  object
#  19  recall_initiation_date      23764 non-null  datetime64[ns]
#  20  center_classification_date  23764 non-null  datetime64[ns]
#  21  termination_date            23764 non-null  datetime64[ns]
#  22  report_date                 23764 non-null  datetime64[ns]
#  23  code_info                   23764 non-null  object
#  24  more_code_info              10212 non-null  object
#  25  duration                    23764 non-null  timedelta64[ns]
# dtypes: datetime64[ns](4), object(21), timedelta64[ns](1)
# memory usage: 4.9+ MB

# %%
duration_df = duration_df.sort_values("duration")

# %%
duration_df["duration"].head()
# Out:
# 20008   5 days
# 1052    7 days
# 18369   7 days
# 14869   7 days
# 24960   7 days
# Name: duration, dtype: timedelta64[ns]

# %%
duration_df["duration"].describe()
# Out:
# count                          23764
# mean     341 days 05:59:23.642484428
# std      345 days 19:04:49.373660560
# min                  5 days 00:00:00
# 25%                102 days 00:00:00
# 50%                218 days 00:00:00
# 75%                489 days 00:00:00
# max               3437 days 00:00:00
# Name: duration, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
ax = duration_df["duration"].dt.days.hist(
    bins=20,
    color="#3498db",
    edgecolor="white",
    alpha=0.8
)

plt.title("Distribution of Duration (Days)", fontsize=16, fontweight="bold", pad=20)
plt.xlabel("Duration (Days)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
df['duration_days'] = df['duration'].dt.days
monthly_average = df.groupby(pd.Grouper(key='recall_initiation_date', freq='QE'))['duration_days'].mean()

# Plotting the average duration per quarter
plt.plot(monthly_average.index, monthly_average, marker='.', linestyle='-', color="cornflowerblue")
plt.title('Average Recall Duration Per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Average Duration (days)')
plt.grid()
plt.xticks(rotation=45)
plt.show()
