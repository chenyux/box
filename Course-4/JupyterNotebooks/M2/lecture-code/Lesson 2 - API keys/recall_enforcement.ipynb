# %% [markdown]
# # Recall Enforcement Analysis

# %%
import requests

# %%
url = "https://2eraiuh.dlai.link/api/facilities"

params = {
    
}

response = requests.get(url, params=params)
data = response.json()
data
# Out:
# {'error': 'Unauthorized - Invalid or missing API key'}

# %%
# Loads API key & saves it into variable API key
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("FOOD_SAFETY_API_KEY")

# %%
api_key
# Out:
# 'sk_test_7AH92K4jd8E5F1vPzQrX3sT9Ln6m2Di_bJe8W3vYp0N4zU6xR7w'

# %%
url = "https://2eraiuh.dlai.link/api/facilities"

params = {
    "api_key": api_key
}

response = requests.get(url, params=params)
data = response.json()
data
# Out:
# {'data': [{'critical_violations': 0,
#    'days_since_last_inspection': 267,
#    'employee_count': 182,
#    'facility_id': 'FAC001',
#    'facility_name': 'Tropical Harvest Oasis Operations',
#    'inspection_date': '2024-05-16',
#    'non_critical_violations': 2,
#    'previous_score': 75,
#    'production_volume': 11383,
#    'risk_category': 'Medium',
#    'shifts_per_day': 2,
#    'square_footage': 182969,
#    'state': 'AZ',
#    'total_score': 76,
#    'training_hours_monthly': 482},
#   {'critical_violations': 1,
#    'days_since_last_inspection': 191,
#    'employee_count': 121,
#    'facility_id': 'FAC002',
#    'facility_name': 'Blue Ridge Harvest House',
#    'inspection_date': '2024-07-31',
#    'non_critical_violations': 2,
#    'previous_score': 66,
#    'production_volume': 6091,
#    'risk_category': 'Medium',
#    'shifts_per_day': 1,
#    'square_footage': 121579,
#    'state': 'KS',
#    'total_score': 77,
#    'training_hours_monthly': 322},
#   {'critical_violations': 1,
#    'days_since_last_inspection': 187,
#    'employee_count': 116,
#    'facility_id': 'FAC003',
#    'facility_name': 'Ocean Harvest Alchemy Works',
#    'inspection_date': '2024-08-04',
#    'non_critical_violations': 3,
#    'previous_score': 78,
#    'production_volume': 10481,
#    'risk_category': 'Medium',
#    'shifts_per_day': 2,
#    'square_footage': 116611,
#    'state': 'SD',
#    'total_score': 80,
#    'training_hours_monthly': 306},
#   {'critical_violations': 2,
#    'days_since_last_inspection': 44,
#    'employee_count': 133,
#    'facility_id': 'FAC004',
#    'facility_name': 'Epicurean Summit Enterprises',
#    'inspection_date': '2024-12-25',
#    'non_critical_violations': 3,
#    'previous_score': 94,
#    'production_volume': 6586,
#    'risk_category': 'Low',
#    'shifts_per_day': 1,
#    'square_footage': 133480,
#    'state': 'RI',
#    'total_score': 99,
#    'training_hours_monthly': 398},
#   {'critical_violations': 2,
#    'days_since_last_inspection': 32,
#    'employee_count': 201,
#    'facility_id': 'FAC005',
#    'facility_name': 'Harbor Harvest Pantry House',
#    'inspection_date': '2025-01-06',
#    'non_critical_violations': 2,
#    'previous_score': 66,
#    'production_volume': 14638,
#    'risk_category': 'Medium',
#    'shifts_per_day': 2,
#    'square_footage': 201546,
#    'state': 'HI',
#    'total_score': 76,
#    'training_hours_monthly': 673},
#   {'critical_violations': 2,
#    'days_since_last_inspection': 27,
#    'employee_count': 213,
#    'facility_id': 'FAC006',
#    'facility_name': 'Echo Peak Culinary Labs',
#    'inspection_date': '2025-01-11',
#    'non_critical_violations': 1,
#    'previous_score': 84,
#    'production_volume': 20000,
#    'risk_category': 'Low',
#    'shifts_per_day': 2,
#    'square_footage': 213948,
#    'state': 'VA',
#    'total_score': 91,
#    'training_hours_monthly': 1401},
#   {'critical_violations': 0,
#    'days_since_last_inspection': 232,
#    'employee_count': 240,
#    'facility_id': 'FAC007',
#    'facility_name': 'Elevate Prairie Harvest Co.',
#    'inspection_date': '2024-06-20',
#    'non_critical_violations': 6,
#    'previous_score': 87,
#    'production_volume': 10230,
#    'risk_category': 'Medium',
#    'shifts_per_day': 2,
#    'square_footage': 240452,
#    'state': 'WI',
#    'total_score': 84,
#    'training_hours_monthly': 732},
#   {'critical_violations': 1,
#    'days_since_last_inspection': 331,
#    'employee_count': 133,
#    'facility_id': 'FAC008',
#    'facility_name': 'Harbor Harvest Cuisine Co.',
#    'inspection_date': '2024-03-13',
#    'non_critical_violations': 1,
#    'previous_score': 64,
#    'production_volume': 9289,
#    'risk_category': 'High',
#    'shifts_per_day': 1,
#    'square_footage': 133090,
#    'state': 'GA',
#    'total_score': 69,
#    'training_hours_monthly': 279},
#   {'critical_violations': 4,
#    'days_since_last_inspection': 318,
#    'employee_count': 183,
#    'facility_id': 'FAC009',
#    'facility_name': 'HarborBloom Edibles GroupLayout',
#    'inspection_date': '2024-03-26',
#    'non_critical_violations': 1,
#    'previous_score': 80,
#    'production_volume': 20000,
#    'risk_category': 'Medium',
#    'shifts_per_day': 2,
#    'square_footage': 183316,
#    'state': 'NV',
#    'total_score': 80,
#    'training_hours_monthly': 1139},
#   {'critical_violations': 2,
#    'days_since_last_inspection': 81,
#    'employee_count': 133,
#    'facility_id': 'FAC010',
#    'facility_name': 'SeaSprout Oasis Backend Processing',
#    'inspection_date': '2024-11-18',
#    'non_critical_violations': 5,
#    'previous_score': 83,
#    'production_volume': 2358,
#    'risk_category': 'Medium',
#    'shifts_per_day': 1,
#    'square_footage': 133466,
#    'state': 'CT',
#    'total_score': 87,
#    'training_hours_monthly': 334}],
#  'metadata': {'limit': 10, 'offset': 0, 'total_inspections': 15000},
#  'success': True}

# %%
data.keys()
# Out:
# dict_keys(['data', 'metadata', 'success'])

# %%
len(data["data"])
# Out:
# 10

# %%
data["data"][0]
# Out:
# {'critical_violations': 0,
#  'days_since_last_inspection': 267,
#  'employee_count': 182,
#  'facility_id': 'FAC001',
#  'facility_name': 'Tropical Harvest Oasis Operations',
#  'inspection_date': '2024-05-16',
#  'non_critical_violations': 2,
#  'previous_score': 75,
#  'production_volume': 11383,
#  'risk_category': 'Medium',
#  'shifts_per_day': 2,
#  'square_footage': 182969,
#  'state': 'AZ',
#  'total_score': 76,
#  'training_hours_monthly': 482}

# %%
url = "https://2eraiuh.dlai.link/api/facilities"

params = {
    "api_key": api_key,
    "limit": 1000
}

response = requests.get(url, params=params)
data = response.json()

# %%
import pandas as pd

# %%
df = pd.DataFrame(data["data"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   critical_violations         1000 non-null   int64
#  1   days_since_last_inspection  1000 non-null   int64
#  2   employee_count              1000 non-null   int64
#  3   facility_id                 1000 non-null   object
#  4   facility_name               1000 non-null   object
#  5   inspection_date             1000 non-null   object
#  6   non_critical_violations     1000 non-null   int64
#  7   previous_score              1000 non-null   int64
#  8   production_volume           1000 non-null   int64
#  9   risk_category               1000 non-null   object
#  10  shifts_per_day              1000 non-null   int64
#  11  square_footage              1000 non-null   int64
#  12  state                       1000 non-null   object
#  13  total_score                 1000 non-null   int64
#  14  training_hours_monthly      1000 non-null   int64
# dtypes: int64(10), object(5)
# memory usage: 117.3+ KB

# %%
df.describe()
# Out:
#        critical_violations  days_since_last_inspection  employee_count  \
# count          1000.000000                 1000.000000      1000.00000
# mean              1.444000                  182.355000       161.45600
# std               1.169715                  106.669205        60.01433
# min               0.000000                    0.000000        50.00000
# 25%               1.000000                   85.000000       116.00000
# 50%               1.000000                  184.000000       151.00000
# 75%               2.000000                  277.250000       199.25000
# max               6.000000                  364.000000       300.00000
#
#        non_critical_violations  previous_score  production_volume  \
# count                1000.0000     1000.000000        1000.000000
# mean                    3.0100       81.844000       11113.257000
# std                     1.6795        9.066635        5402.197003
# min                     0.0000       60.000000        2000.000000
# 25%                     2.0000       76.000000        6476.500000
# 50%                     3.0000       82.000000       10258.500000
# 75%                     4.0000       88.000000       15534.000000
# max                     9.0000      100.000000       20000.000000
#
#        shifts_per_day  square_footage  total_score  training_hours_monthly
# count     1000.000000     1000.000000  1000.000000             1000.000000
# mean         1.514000   161917.345000    84.566000              568.057000
# std          0.500054    59973.911378     7.856804              575.876038
# min          1.000000    50000.000000    60.000000              134.000000
# 25%          1.000000   116923.500000    79.000000              331.000000
# 50%          2.000000   151300.500000    85.000000              466.000000
# 75%          2.000000   199969.000000    90.000000              647.250000
# max          2.000000   300000.000000   100.000000            10520.000000

# %%
df["total_violations"] = df["critical_violations"] + df["non_critical_violations"]

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    shifts_per_day  square_footage state  total_score  training_hours_monthly  \
# 0               2          182969    AZ           76                     482
# 1               1          121579    KS           77                     322
# 2               2          116611    SD           80                     306
# 3               1          133480    RI           99                     398
# 4               2          201546    HI           76                     673
#
#    total_violations
# 0                 2
# 1                 3
# 2                 4
# 3                 5
# 4                 4

# %%
df["scaled_violations"] = df["total_violations"] / df["square_footage"]

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    shifts_per_day  square_footage state  total_score  training_hours_monthly  \
# 0               2          182969    AZ           76                     482
# 1               1          121579    KS           77                     322
# 2               2          116611    SD           80                     306
# 3               1          133480    RI           99                     398
# 4               2          201546    HI           76                     673
#
#    total_violations  scaled_violations
# 0                 2           0.000011
# 1                 3           0.000025
# 2                 4           0.000034
# 3                 5           0.000037
# 4                 4           0.000020

# %%
df["scaled_violations"] = df["scaled_violations"] * 100000 # convert to violations per 100,000 sqft

# %%
df["scaled_violations"].describe()
# Out:
# count    1000.000000
# mean        3.195747
# std         2.018113
# min         0.000000
# 25%         1.734258
# 50%         2.753808
# 75%         4.175452
# max        14.174344
# Name: scaled_violations, dtype: float64

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    shifts_per_day  square_footage state  total_score  training_hours_monthly  \
# 0               2          182969    AZ           76                     482
# 1               1          121579    KS           77                     322
# 2               2          116611    SD           80                     306
# 3               1          133480    RI           99                     398
# 4               2          201546    HI           76                     673
#
#    total_violations  scaled_violations
# 0                 2           1.093081
# 1                 3           2.467531
# 2                 4           3.430208
# 3                 5           3.745880
# 4                 4           1.984659

# %%
df["scaled_violations"] = df["scaled_violations"].round(2)

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    shifts_per_day  square_footage state  total_score  training_hours_monthly  \
# 0               2          182969    AZ           76                     482
# 1               1          121579    KS           77                     322
# 2               2          116611    SD           80                     306
# 3               1          133480    RI           99                     398
# 4               2          201546    HI           76                     673
#
#    total_violations  scaled_violations
# 0                 2               1.09
# 1                 3               2.47
# 2                 4               3.43
# 3                 5               3.75
# 4                 4               1.98

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.regplot(
    x="square_footage", 
    y="scaled_violations", 
    data=df
)

plt.xlabel("Square Footage")
plt.ylabel("Scaled Violations")
plt.title("Relationship Between Square Footage and Scaled Violations")

plt.show()

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    shifts_per_day  square_footage state  total_score  training_hours_monthly  \
# 0               2          182969    AZ           76                     482
# 1               1          121579    KS           77                     322
# 2               2          116611    SD           80                     306
# 3               1          133480    RI           99                     398
# 4               2          201546    HI           76                     673
#
#    total_violations  scaled_violations
# 0                 2               1.09
# 1                 3               2.47
# 2                 4               3.43
# 3                 5               3.75
# 4                 4               1.98

# %%
# categorize production volume into low, moderate, and high bins
df["volume_category"] = pd.qcut(df["production_volume"], q=3)

# %%
pd.unique(df["volume_category"])
# Out:
# [(7748.0, 13561.0], (1999.999, 7748.0], (13561.0, 20000.0]]
# Categories (3, interval[float64, right]): [(1999.999, 7748.0] < (7748.0, 13561.0] < (13561.0, 20000.0]]

# %%
df["volume_category"] = pd.qcut(df["production_volume"], 
                                q=3,
                                labels=["low", "moderate", "high"])

# %%
df["volume_category"].value_counts()
# Out:
# volume_category
# high        334
# low         333
# moderate    333
# Name: count, dtype: int64

# %%
df["previous_score"].hist(bins=15)
plt.title("Frequency of Previous Score")
plt.show()

# %%
# create custom bins for previous score
boundaries = [
    df["previous_score"].min(),
    75,
    90,
    df["previous_score"].max()
]

# %%
boundaries
# Out:
# [60, 75, 90, 100]

# %%
df["score_category"] = pd.cut(df["previous_score"], 
                              bins=boundaries, 
                              labels=["at risk", "average","excellent"])

# %%
df["score_category"].value_counts()
# Out:
# score_category
# average      573
# at risk      235
# excellent    181
# Name: count, dtype: int64

# %%
df["score_category"].value_counts(normalize=True)
# Out:
# score_category
# average      0.579373
# at risk      0.237614
# excellent    0.183013
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    shifts_per_day  square_footage state  total_score  training_hours_monthly  \
# 0               2          182969    AZ           76                     482
# 1               1          121579    KS           77                     322
# 2               2          116611    SD           80                     306
# 3               1          133480    RI           99                     398
# 4               2          201546    HI           76                     673
#
#    total_violations  scaled_violations volume_category score_category
# 0                 2               1.09        moderate        at risk
# 1                 3               2.47             low        at risk
# 2                 4               3.43        moderate        average
# 3                 5               3.75             low      excellent
# 4                 4               1.98            high        at risk

# %%
# calculates each value minus min / range
from helper_functions import normalize

# %%
normalize(df["days_since_last_inspection"])
# Out:
# 0      0.733516
# 1      0.524725
# 2      0.513736
# 3      0.120879
# 4      0.087912
#          ...
# 995    0.708791
# 996    0.126374
# 997    0.258242
# 998    0.598901
# 999    0.994505
# Name: days_since_last_inspection, Length: 1000, dtype: float64

# %%
# lower values are better
1 - normalize(df["days_since_last_inspection"])
# Out:
# 0      0.266484
# 1      0.475275
# 2      0.486264
# 3      0.879121
# 4      0.912088
#          ...
# 995    0.291209
# 996    0.873626
# 997    0.741758
# 998    0.401099
# 999    0.005495
# Name: days_since_last_inspection, Length: 1000, dtype: float64

# %%
df["days_normalized"] = 1 - normalize(df["days_since_last_inspection"])

# %%
df["violations_normalized"] = 1 - normalize(df["scaled_violations"])

# %%
df["violations_normalized"].hist()
# Out:
# <Axes: >

# %%
df["scaled_violations"].hist()
# Out:
# <Axes: >

# %%
df["composite_score"] = (0.3*df["days_normalized"]
                        + 0.7*df["violations_normalized"]) * 100

# %%
df["composite_score"] = df["composite_score"].round(2)

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    ...  state  total_score training_hours_monthly  total_violations  \
# 0  ...     AZ           76                    482                 2
# 1  ...     KS           77                    322                 3
# 2  ...     SD           80                    306                 4
# 3  ...     RI           99                    398                 5
# 4  ...     HI           76                    673                 4
#
#    scaled_violations  volume_category  score_category days_normalized  \
# 0               1.09         moderate         at risk        0.266484
# 1               2.47              low         at risk        0.475275
# 2               3.43         moderate         average        0.486264
# 3               3.75              low       excellent        0.879121
# 4               1.98             high         at risk        0.912088
#
#   violations_normalized  composite_score
# 0              0.923077            72.61
# 1              0.825688            72.06
# 2              0.757939            67.64
# 3              0.735356            77.85
# 4              0.860268            87.58
#
# [5 rows x 22 columns]

# %%
df["training_hours_per_employee"] = df["training_hours_monthly"] / df["employee_count"]

# %%
df.head()
# Out:
#    critical_violations  days_since_last_inspection  employee_count  \
# 0                    0                         267             182
# 1                    1                         191             121
# 2                    1                         187             116
# 3                    2                          44             133
# 4                    2                          32             201
#
#   facility_id                      facility_name inspection_date  \
# 0      FAC001  Tropical Harvest Oasis Operations      2024-05-16
# 1      FAC002           Blue Ridge Harvest House      2024-07-31
# 2      FAC003        Ocean Harvest Alchemy Works      2024-08-04
# 3      FAC004       Epicurean Summit Enterprises      2024-12-25
# 4      FAC005        Harbor Harvest Pantry House      2025-01-06
#
#    non_critical_violations  previous_score  production_volume risk_category  \
# 0                        2              75              11383        Medium
# 1                        2              66               6091        Medium
# 2                        3              78              10481        Medium
# 3                        3              94               6586           Low
# 4                        2              66              14638        Medium
#
#    ...  total_score  training_hours_monthly total_violations  \
# 0  ...           76                     482                2
# 1  ...           77                     322                3
# 2  ...           80                     306                4
# 3  ...           99                     398                5
# 4  ...           76                     673                4
#
#    scaled_violations  volume_category  score_category  days_normalized  \
# 0               1.09         moderate         at risk         0.266484
# 1               2.47              low         at risk         0.475275
# 2               3.43         moderate         average         0.486264
# 3               3.75              low       excellent         0.879121
# 4               1.98             high         at risk         0.912088
#
#   violations_normalized composite_score  training_hours_per_employee
# 0              0.923077           72.61                     2.648352
# 1              0.825688           72.06                     2.661157
# 2              0.757939           67.64                     2.637931
# 3              0.735356           77.85                     2.992481
# 4              0.860268           87.58                     3.348259
#
# [5 rows x 23 columns]

# %%
sns.boxplot(x=df["training_hours_per_employee"])
# Out:
# <Axes: xlabel='training_hours_per_employee'>

# %%
df = df[df["training_hours_per_employee"] < 20]

# %%
df["training_hours_per_employee"].hist()
# Out:
# <Axes: >

# %%
df["training_z_score"] = (df["training_hours_per_employee"] 
                          - df["training_hours_per_employee"].mean()) / df["training_hours_per_employee"].std()

# %%
nonoutlier_df = df[df["training_z_score"] <= 3]

# %%
outlier_df = df[df["training_z_score"] > 3]

# %%
nonoutlier_df["production_volume"].mean()
# Out:
# np.float64(10904.022564102565)

# %%
outlier_df["production_volume"].mean()
# Out:
# np.float64(20000.0)
