# %% [markdown]
# # Confidence intervals

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats

# %%
df = pd.read_csv("diamonds.csv")

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53941.000000  53941.000000  53941.000000  53941.000000  53941.000000
# mean       0.797953     61.749447     57.457231   3932.885875      5.731183
# std        0.474016      1.432641      2.234497   3989.452937      1.121767
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5325.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53941.000000  53941.000000
# mean       5.734554      3.538753
# std        1.142143      0.705707
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
sns.histplot(df, x="price")
plt.show()

# %%
n = df["price"].count() # number of diamonds
xbar = df["price"].mean()
s = df["price"].std()
conf = 0.95
SEM = s / np.sqrt(n)

# %%
interval = stats.norm.interval(confidence=conf, loc=xbar, scale=SEM)
interval
# Out:
# (np.float64(3899.219067451682), np.float64(3966.5526831647326))

# %%
print("With 95% confidence, the true mean diamond price is between", interval[0], "and", interval[1])
# Out:
# With 95% confidence, the true mean diamond price is between 3899.219067451682 and 3966.5526831647326

# %% [markdown]
# ## One sample t test

# %%
# Test whether "Premium" cut diamonds have an average price above $4500
# look at individual values for cut - 5 different options
print(pd.unique(df["cut"]))
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
# find the mean of prices for different cuts
df.groupby("cut")["price"].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3929.812309
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
alpha = 0.05
test_results = stats.ttest_1samp(df[df["cut"] == "Premium"]["price"], popmean=4500)
print(test_results)
# Out:
# TtestResult(statistic=np.float64(2.275084997124123), pvalue=np.float64(0.02291611091679631), df=np.int64(13790))

# %%
if test_results[1] > alpha:
    print("Failed to reject the null with p-value", test_results[1])
else:
    print("Rejected the null with p-value", test_results[1])
# Out:
# Rejected the null with p-value 0.02291611091679631

# %% [markdown]
# # Two sample t test

# %%
# plot differences
df.groupby("cut")["price"].mean().sort_values().plot(kind="bar")
plt.show()

# %%
df.groupby("cut")["price"].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3929.812309
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
sns.boxplot(df, x="price", y="cut", palette="terrain")
# Out:
# /tmp/ipykernel_220/3950482505.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df, x="price", y="cut", palette="terrain")
# <Axes: xlabel='price', ylabel='cut'>

# %%
very_good_df = df[df["cut"] == "Very Good"]
good_df = df[df["cut"] == "Good"]
test_results = stats.ttest_ind(very_good_df["price"], good_df["price"])

# %%
print(test_results)
# Out:
# TtestResult(statistic=np.float64(0.7941427626594914), pvalue=np.float64(0.4271234189400054), df=np.float64(16987.0))

# %%
if test_results[1] > 0.05:
    print("Failed to reject the null with p-value", test_results[1])
else:
    print("Rejected the null with p-value", test_results[1])
# Out:
# Failed to reject the null with p-value 0.4271234189400054

# %% [markdown]
# # Simulation

# %%
n = 1000
sample = np.random.uniform(low=0, high=0.1, size=n)
xbar = sample.mean()
s = sample.std()
print("Sample mean:", xbar)
print("Sample st. dev.:", s)
sns.histplot(sample)
plt.show()
# Out:
# Sample mean: 0.05103068509933112
# Sample st. dev.: 0.028531814942533082

# %%
n = 1000
sample = np.random.uniform(low=0, high=0.1, size=n)
xbar = sample.mean()
s = sample.std()
conf = 0.95
SEM = s / np.sqrt(n)
print("Sample mean:", xbar)
print("Sample st. dev.:", s)
interval = stats.norm.interval(confidence=conf, loc=xbar, scale=SEM)
print("With 95% confidence, the true mean diamond price is between", interval[0], "and", interval[1])
sns.histplot(sample)
plt.show()
# Out:
# Sample mean: 0.04955855485221293
# Sample st. dev.: 0.028728494079955074
# With 95% confidence, the true mean diamond price is between 0.047777977060578215 and 0.051339132643847644

# %%
# Ask LLM to repeat scenario:
n = 1000
conf = 0.95
contains_0_05 = 0
does_not_contain_0_05 = 0

for _ in range(100):
    sample = np.random.uniform(low=0, high=0.1, size=n)
    xbar = sample.mean()
    s = sample.std()
    SEM = s / np.sqrt(n)
    interval = stats.norm.interval(confidence=conf, loc=xbar, scale=SEM)
    
    if interval[0] <= 0.05 <= interval[1]:
        contains_0_05 += 1
    else:
        does_not_contain_0_05 += 1

print("Number of intervals containing 0.05:", contains_0_05)
print("Number of intervals not containing 0.05:", does_not_contain_0_05)
# Out:
# Number of intervals containing 0.05: 95
# Number of intervals not containing 0.05: 5

# %% [markdown]
# ## Sampling from the normal distribution

# %%
n = 1000
conf = 0.95

for _ in range(100):
    sample = np.random.normal(loc=3932, scale=750, size=n)
    xbar = sample.mean()
    s = sample.std()
    SEM = s / np.sqrt(n)
    interval = stats.norm.interval(confidence=conf, loc=xbar, scale=SEM)
    print(interval)
# Out:
# (np.float64(3870.5403296267805), np.float64(3965.394815054735))
# (np.float64(3891.3381988356496), np.float64(3984.703845456158))
# (np.float64(3877.466882112533), np.float64(3970.093869898826))
# (np.float64(3918.987574580699), np.float64(4009.949065882823))
# (np.float64(3863.9193879134677), np.float64(3958.574375726254))
# (np.float64(3899.400776123748), np.float64(3996.2496087009504))
# (np.float64(3885.3164835465054), np.float64(3977.4640057783995))
# (np.float64(3846.7624358549588), np.float64(3940.9615669042164))
# (np.float64(3885.5703176944235), np.float64(3976.8600680433337))
# (np.float64(3879.011544301036), np.float64(3971.2343659260873))
# (np.float64(3868.448700030642), np.float64(3960.9533270463958))
# (np.float64(3852.3896814458226), np.float64(3945.475111248916))
# (np.float64(3890.232859693501), np.float64(3983.183509838505))
# (np.float64(3877.6544881125433), np.float64(3969.985351938268))
# (np.float64(3877.2113509221654), np.float64(3970.7128510293514))
# (np.float64(3882.593410613991), np.float64(3977.944488767136))
# (np.float64(3900.406455308378), np.float64(3992.8657214607465))
# (np.float64(3871.047629911805), np.float64(3962.2382793209676))
# (np.float64(3911.2299728981143), np.float64(4006.0289834144205))
# (np.float64(3887.7481079178333), np.float64(3983.1430304520254))
# (np.float64(3862.8349764725676), np.float64(3954.615031730063))
# (np.float64(3885.736625988979), np.float64(3978.4706999395544))
# (np.float64(3934.762684429629), np.float64(4026.617214340912))
# (np.float64(3890.120740295295), np.float64(3980.841135551461))
# (np.float64(3871.4588357713383), np.float64(3961.5762269973075))
# (np.float64(3905.2923519371043), np.float64(3997.923293759741))
# (np.float64(3903.6864776149014), np.float64(3994.524927995043))
# (np.float64(3860.715289214803), np.float64(3952.0635218697075))
# (np.float64(3861.8116043308014), np.float64(3956.907853753048))
# (np.float64(3865.37527144881), np.float64(3959.1623944133653))
# (np.float64(3900.6450711224006), np.float64(3992.8735078277696))
# (np.float64(3893.188820020361), np.float64(3986.4963187779485))
# (np.float64(3890.5616110328956), np.float64(3985.5329310645893))
# (np.float64(3867.9733815458844), np.float64(3957.3059992039002))
# (np.float64(3886.74761838049), np.float64(3981.9081512065595))
# (np.float64(3926.3642610721017), np.float64(4019.1142342864296))
# (np.float64(3909.373785587534), np.float64(4004.8854693006665))
# (np.float64(3926.362832593437), np.float64(4019.500171870998))
# (np.float64(3924.8356971634103), np.float64(4017.0645250943317))
# (np.float64(3881.4013748560096), np.float64(3974.880270219411))
# (np.float64(3882.049004249357), np.float64(3978.813837985336))
# (np.float64(3887.730660987933), np.float64(3980.08322461111))
# (np.float64(3861.6624830038254), np.float64(3953.7880587125183))
# (np.float64(3869.7115612606804), np.float64(3964.3083435807803))
# (np.float64(3890.4789421040196), np.float64(3981.0008848344232))
# (np.float64(3894.3359743521455), np.float64(3987.084337905066))
# (np.float64(3877.1944769409297), np.float64(3968.774768575389))
# (np.float64(3918.758323024901), np.float64(4012.8193624279065))
# (np.float64(3859.44297466896), np.float64(3953.2694418623746))
# (np.float64(3944.3197114156246), np.float64(4037.168756610802))
# (np.float64(3900.258877715177), np.float64(3993.0271032760866))
# (np.float64(3889.7568985732983), np.float64(3984.343827895323))
# (np.float64(3936.6874089358407), np.float64(4030.953507886272))
# (np.float64(3903.3199760141606), np.float64(3996.4991469760744))
# (np.float64(3884.840609424077), np.float64(3977.313425901006))

# %%
n = 1000
conf = 0.95
contains_mu = 0
does_not_contain_mu = 0

for _ in range(100):
    sample = np.random.normal(loc=3932, scale=750, size=n)
    xbar = sample.mean()
    s = sample.std()
    SEM = s / np.sqrt(n)
    interval = stats.norm.interval(confidence=conf, loc=xbar, scale=SEM)
    
    if interval[0] <= 3932 <= interval[1]:
        contains_mu += 1
    else:
        does_not_contain_mu += 1

print("Number of intervals containing 3932:", contains_mu)
print("Number of intervals not containing 3932:", does_not_contain_mu)
# Out:
# Number of intervals containing 3932: 94
# Number of intervals not containing 3932: 6
