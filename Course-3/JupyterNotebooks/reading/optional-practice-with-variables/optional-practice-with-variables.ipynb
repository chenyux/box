# %% [markdown]
# # [Optional] Practice with variables
#
# Use these code exercises to practice working with variables! These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Python.

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Instructions
#
# 1. Create a variable named `x` with the value 5
# 2. Create a variable named `y` with the value 3.5
# 3. Create a variable named `text` with the value "I am having a blast!"

# %% [markdown]
# **Expected output:**
#
# No Output
#
# Since you are saving values into variables and not printing anything, then there should be no output

# %% [markdown]
# ## Exercise 2:
#
# Now, combine the variables with printing and commenting

# %% [markdown]
# ### Instructions
#
# 1. Print the text "Hi, what is your name?"
# 2. Create a variable called `my_name`, and assign your name to it.
# 3. Create a comment line that says "Print out welcome message". Remember that to comment a line in python you can put the symbol `#` at the beginning of the line.
# 4. Print the message "Hi {my_name}! Welcome to the course". You can do this with the code `print("Hi", my_name, "! Welcome to the course")`
# 5. What happens if you comment the two print lines by putting a `#` at the start of the line? Do you get any outputs?

# %% [markdown]
# **Expected output:**
#
# Hi Magui ! Welcome to the course
#
# You should see your name printed out alongside the message.

# %% [markdown]
# ## Exercise 3: Variable types

# %% [markdown]
# ### Instructions
#
# Before the print functions already in place:
#
# 1. Create a variable `age` that stores your age (integer).
# 2. Create a variable `height` that stores your height in meters or inches (include a decimal even if it is .0) (float).
# 3. Create a variable `intro` that stores a short sentence about yourself (string).
# 4. Use the already filled print functions to print the data types of each variable.

# %%
### START CODE HERE ###

### END CODE HERE ###

print("Variable age is of type", type(age))
print("Variable height is of type", type(height))
print("Variable intro is of type", type(intro))

# %% [markdown]
# **Expected output:**
#
# Variable age is of type <class 'int'>
#
# Variable height is of type <class 'float'>
#
# Variable intro is of type <class 'str'>

# %% [markdown]
# ## SOLUTIONS

# %% [markdown]
# ### Exercise 1:
# ```
# x = 5
# y = 3.5
# text = "I am having a blast!"
# ```

# %% [markdown]
# ### Exercise 2:
# ```
# my_name = "Name"
# # Print out welcome message
# print("Hi", my_name, "! Welcome to the course")
# ```

# %% [markdown]
# ### Exercise 3:
# ```
# age = 27
# height = 168.5
# intro = "I am a friendly person"
# ```
