# %% [markdown]
# # [Optional] Practice with descriptive statistics
#
# Use these code exercises to practice working with descriptive statistics on numerical and categorical data. These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Pandas.

# %% [markdown]
# ## Exercise 1: Calculating mean and median
#
# You have a DataFrame called `grades` containing the scores of your students on an exam and their participation level in class. You can run the code below to see the dataframe.

# %%
import pandas as pd

grades = pd.DataFrame({
    "student": ["Amara", "Javier", "Fatima", "Lina", "Kenji"],
    "score": [88, 92, 85, 91, 87],
    "participation": ["High", "Medium", "High", "Low", "Medium"]
})

print(grades)

# %% [markdown]
# First, you want to measure the central tendency of the distribution of scores.
#
# ### Instructions
#
# - Calculate the mean and median of the `score` column.
# - Print each result. Feel free to add text to give more context to each value.

# %%
# get the mean of the scores


# get the median of the scores


# print both results

# %% [markdown]
# **Expected output**
#
# ```
# The mean of the scores is 88.6
# The median of the scores is 88.0
# ```

# %% [markdown]
# ## Exercise 2: Measuring the standard deviation
#
# You can also describe the variability among the scores.
#
# ### Instructions
#
# Using the same DataFrame `grades`:
#
# - Find the standard deviation of the `score` column.
# - Print the result.

# %%
# get the standard deviation of the scores


# print the result

# %% [markdown]
# **Expected output:**
#
# ```
# The standard deviation of the scores is 2.8809720581775866
# ```

# %% [markdown]
# ## Exercise 3: Calculating skewness
#
# ### Instructions
#
# Using the same DataFrame `grades`:
#
# - Calculate the skewness of `score` column.
# - Print the result.

# %%
# calculate the skewness of the scores


# print the result

# %% [markdown]
# **Expected results:**
#
# ```
# The skewness of the scores is 0.03763789885847734
# ```

# %% [markdown]
# ## Exercise 4: Calculating percentiles
#
# ### Instructions
#
# Using the same DataFrame `grades`:
#
# - Find the 25th, 50th, and 75th percentiles of Score.
# - Print the results.

# %%
# use the quantile method to get the 25th, 50th, and 75th percentile scores


# print the results

# %% [markdown]
# Hint: Use the `quantile()` method on your DataFrame. Remember that to calculate multiple percentiles, you can create a list to pass as an argument to the `quantile()` method.
#
# **Expected output:**
#
# ```
# The 25th percentile score is: 87.0
# The 50th percentile score is: 88.0
# The 75th percentile score is: 91.0
# ```

# %% [markdown]
# ## Exercise 5: Counting unique categorical values
#
# The `grades` DataFrame also contains the participation levels for each student. You want to tally how many are in each category: High, Medium, and Low.
#
# ### Instructions
#
# - Use `value_counts()` to count each unique category in the `participation` column.

# %%
# use `value_counts()` to show the participation levels in the dataset

# %% [markdown]
# **Expected output:**
#
# ```
# participation
# High      2
# Medium    2
# Low       1
# Name: count, dtype: int64
# ```

# %% [markdown]
# ## SOLUTIONS:
#
# ## Exercise 1:
#
# ```python
# # get the mean of the scores
# mean = grades['score'].mean()
# ```
#
# ```python
# # get the median of the scores
# median = grades['score'].median()
# ```
#
# ```python
# # print both results
# print("The mean of the scores is: ", mean)
# print("The median of the scores is: ", median)
# ```
#
# ## Exercise 2:
#
# ```python
# # get the standard deviation of the scores
# stdev = grades['score'].std()
# ```
#
# ```python
# # print the result
# print("The standard deviation of the scores is: ", stdev)
# ```
#
# ## Exercise 3:
#
# ```python
# # calculate the skewness of the scores
# skewness = grades['score'].skew()
# ```
#
# ```python
# # print the result
# print("The skewness of the scores is: ", skewness)
# ```
#
# ## Exercise 4:
#
# ```python
# # use the quantile method to get the 25th, 50th, and 75th percentile scores
# score_percentiles = grades['score'].quantile([0.25, 0.5, 0.75])
# ```
#
# ```python
# # print the results
# print("The 25th percentile score is: ", score_percentiles[0.25])
# print("The 50th percentile score is: ", score_percentiles[0.5])
# print("The 75th percentile score is: ", score_percentiles[0.75])
# ```
#
# ## Exercise 5:
#
# ```python
# # use `value_counts()` to show the participation levels in the dataset
# grades['participation'].value_counts()
# ```
