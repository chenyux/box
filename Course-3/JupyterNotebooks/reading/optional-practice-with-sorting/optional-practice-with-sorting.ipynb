# %% [markdown]
# # [Optional] Practice with sorting
#
# Use these code exercises to practice working with sorting. These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Pandas.

# %% [markdown]
# ## Exercise 1: Sorting by one condition
#
# Your company sells different products, and you want to know which are the priciest. You are given a DataFrame named `products` with information about the different products. `products` has columns `product` and `price` as shown when you run the cell below.

# %%
import pandas as pd

products = pd.DataFrame({
    "product": ["Laptop", "Smartphone", "Headphones", "Monitor", "Keyboard"],
    "price": [1200, 799, 150, 300, 45]
})

# print the products dataframe
products

# %% [markdown]
# ### Instructions
#
# - Use the `sort_values()` method to sort the DataFrame by price in descending order (highest to lowest).

# %%
# sort the `products` dataframe by price in descending order

# %% [markdown]
# **Hint:** You can select the column you want to sort by with the parameter `by` set to the name of the column. You can select the ascending order by setting the parameter `ascending` to `False`.
#
# **Expected output:**
#
# ```
#       product  price
# 0      Laptop   1200
# 1  Smartphone    799
# 3     Monitor    300
# 2  Headphones    150
# 4    Keyboard     45
# ```

# %% [markdown]
# ## Exercise 2: Sorting by multiple columns
#
# You wish to organize your employees' information better, so you decide to sort the `employees` DataFrame. You want to sort them by tenure and name.

# %%
import pandas as pd

employees = pd.DataFrame({
    "name": ["Alice Smith", "Charlie Williams", "Rob Johnson",
             "Rohna Brown", "Ethan Jones"],
    "age": [28, 45, 34, 29, 50],
    "job_title": ["Data Analyst", "Senior Developer", "Project Manager", "HR Specialist", "Director"],
    "tenure": [3, 10, 1, 5, 1]
})

print(employees)

# %% [markdown]
# ### Instructions
#
# - Specify the columns you want to sort. Put them in a list.
# - Specify how each column is sorted. Tenure should be descending while name is ascending. Put them in a list.
# - Use `sort_values()` to sort the `employees` DataFrame by tenure (descending), and name (ascending).

# %%
# put the column names you want to sort in a list


# put the order you want to sort each column in a list


# use the sort_values() method to sort the columns in the order you specified

# %% [markdown]
# **Expected output:**
#
# ```
#                name  age         job_title  tenure
# 1  Charlie Williams   45  Senior Developer      10
# 3       Rohna Brown   29     HR Specialist       5
# 0       Alice Smith   28      Data Analyst       3
# 4       Ethan Jones   50          Director       1
# 2       Rob Johnson   34   Project Manager       1
# ```
#
# **Hint:** you can again use the method `sort_values`. This time, argument `by` should be set to the list of columns you want to use for sorting (the order of the list is important!), and `ascending` should also be a list, one element for each column name.

# %% [markdown]
# ## SOLUTIONS:
#
# ## Exercise 1:
#
# ```python
# products.sort_values(by='price', ascending=False)
# ```
#
# ## Exercise 2:
#
# ```python
# # put the column names you want to sort in a list
# columns = ['tenure', 'name']
# ```
#
# ```python
# # put the order you want to sort each column in a list
# order = [False, True]
# ```
#
# ```python
# # use the sort_values() method to sort the columns in the order you specified
# employees.sort_values(by=columns, ascending=order)
# ```
