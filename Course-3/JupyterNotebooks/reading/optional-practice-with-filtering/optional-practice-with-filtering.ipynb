# %% [markdown]
# # [Optional] Practice with filtering
#
# Use these code exercises to practice working with filtering DataFrames. These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Pandas.

# %% [markdown]
# ## Exercise 1: Filtering by one condition
#
# As a data analyst at a healthcare organization, you're working with a dataset containing patient IDs, gender, age, and BMI. Your task is to apply filtering techniques to extract insights that can inform medical research and patient care. Run the code below to see the sample DataFrame you'll be working with.

# %%
import pandas as pd

patients = pd.DataFrame({
    "patient_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "gender": ["Female", "Female", "Male", "Male", "Female",
               "Male", "Female", "Female", "Male", "Male"],
    "age": [45, 58, 32, 29, 51, 39, 60, 48, 27, 35],
    "bmi": [31.2, 28.7, 22.3, 33.1, 34.5, 35.4, 30.8, 27.5, 30.8, 32.2]
})

# preview the patients dataframe
print(patients)

# %% [markdown]
# ### Instructions
#
# - Filter the `patients` DataFrame for 'Male' patients and save it in the variable `patients_male`.
# - Print the results.

# %%
# filter the dataframe for 'Male' patients to a variable named patients_male


# print the results

# %% [markdown]
# **Expected output:**
#
# ```
#    patient_id  gender  age   bmi
# 2         103    Male   32  22.3
# 3         104    Male   29  33.1
# 5         106    Male   39  35.4
# 8         109    Male   27  30.8
# 9         110    Male   35  32.2
# ```

# %% [markdown]
# ## Exercise 2: Filtering by multiple conditions
#
# ### Instructions
#
# - Filter the `patients` DataFrame for 'Male' patients with 'bmi' greater than or equal to 30.
# - Save it in the variable `patients_male_highbmi`.
# - Print the new results.

# %%
# filter the dataframe for 'Male' patients with 'bmi' >= 30

# save to a variable named patients_male_highbmi


# print the results

# %% [markdown]
# **Hint:** You can use the `&` operator to multiple conditions. Remember to use parentheses to separate the conditions. For example, `my_var = df[(condition1) & (condition2)]`.
#
# **Expected output:**
#
# ```
#    patient_id  gender  age   bmi
# 3         104    Male   29  33.1
# 5         106    Male   39  35.4
# 8         109    Male   27  30.8
# 9         110    Male   35  32.2
# ```

# %% [markdown]
# ## SOLUTIONS:
#
# ## Exercise 1:
#
# ```python
# # filter the dataframe for 'Male' patients to a variable named patients_male
# patients_male = patients[patients['gender'] == 'Male']
# ```
#
# ```python
# # print the results
# print(patients_male)
# ```
#
# ## Exercise 2:
#
# ```python
# # filter the dataframe for 'Male' patients with 'bmi' >= 30
# # save to a variable named patients_male_highbmi
# patients_male_highbmi = patients[(patients['gender'] == 'Male') & (patients['bmi'] >= 30)]
# ```
#
# ```python
# # print the results
# print(patients_male_highbmi)
# ```
