# %% [markdown]
# # [Optional] Practice with DataFrames
#
# Use these code exercises to practice working with DataFrames. These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Pandas.

# %% [markdown]
# ## Exercise 1: Students DataFrame
#
# You're analyzing student performance data for an education company and want to process student metrics using Python. You will try it out first on a sample file containing a few students.
#
# - Import **pandas** with the alias (i.e. nickname) **pd**.
# - Use **pd.read_csv()** to load **students_sample.csv** to a variable named **students**.
# - View the result using the **head** method.

# %%
# import pandas here

# use pd.read_csv to load "students_sample.csv" to a variable named students

# use students.head() to print the first 5 rows

# %% [markdown]
# **Expected output:**
# ```
#      name  age grade
# 0   Aisha   20     A
# 1  Carlos   21     B
# 2   Zhang   19     A
# 3  Fatima   20     C
# 4    Omar   18     A
# ```

# %% [markdown]
# ## Exercise 2: Understanding your DataFrame: Columns
#
# Which information is stored in your DataFrame?
#
# - Use the **columns** attribute to print the names of all the columns of the **students** DataFrame

# %%
# get the names of the columns of the students dataframe

# %% [markdown]
# **Expected output:**
#
# Index(['name', 'age', 'grade'], dtype='object')

# %% [markdown]
# ## Exercise 3: Understanding your DataFrame: Data types
#
# What types of data are stored into each of the columns in your DataFrame?
#
# - Use the **dtypes** attribute to print the data types found in the **students** DataFrame

# %%
# get the data types found in the students dataframe

# %% [markdown]
# **Expected output:**
# ```
# name     object
# age       int64
# grade    object
# dtype: object
# ```

# %% [markdown]
# ## SOLUTIONS:
#
# ### Exercise 1:
#
# ```python
# # import pandas here
# import pandas as pd
# ```
#
# ```python
# # use pd.read_csv to load `students_sample.csv` to a variable named students
# students = pd.read_csv("students_sample.csv")
# ```
#
# ```python
# # use students.head() to print the first 5 rows
# students.head(5)
# ```
#
# ### Exercise 2:
#
# ```python
# students.columns
# ```
#
# ### Exercise 3:
#
# ```python
# students.dtypes
# ```
