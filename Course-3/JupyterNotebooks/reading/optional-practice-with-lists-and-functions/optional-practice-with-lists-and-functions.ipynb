# %% [markdown]
# # [Optional] Practice with lists and functions
#
# Use these code exercises to practice working with lists and functions! These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Python.

# %% [markdown]
# ## Exercise 1: Creating lists

# %% [markdown]
# ### Instructions
#
# 1. Create a list with the sales figures 177, 201, 359, and 407, and save it in a well-named variable
# 2. Create another list with the employees "Parvati", "Angelo", "Serena", and save it in a well-named variable

# %% [markdown]
# **Expected output:** Since you are saving values into variables, and not printing anything you shouldn't have any outputs.

# %% [markdown]
# ## Exercise 2: Adding elements to a list
#
# 1. Use the code block below to add the values 19 and 20 to the variable `ages`. Use `.append()` rather than typing them directly in the list.
# 2. Print the resulting list.

# %%
ages = [20, 19, 21, 20, 19]
### START CODE HERE ###

# %% [markdown]
# **Expected output:**
#
# [20, 19, 21, 20, 19, 19, 20]
#
# **Hint:** you can use the `append()` function twice.

# %% [markdown]
# ## Exercise 3: Functions for lists

# %% [markdown]
# ### Instructions
#
# There is a list of sales figures in the next code block.
#
# 1. Print the length of the list using the `len()` function.
# 2. Print the sum of its values using the `sum()` function.
# 3. Print the minimum value using the `min()` function.
# 4. Print the maximum value using the `max()` function.
# 5. Print the average of the values in the list. **Hint**: there is no mean or average function, but you can do it using some of the previous calculations.

# %%
sales = [1250, 2700, 3935, 1045, 2220]

# %% [markdown]
# **Expected value:**
#
# 1. 5
# 2. 11150
# 3. 1045
# 4. 3935
# 6. 2230.0

# %% [markdown]
# ## SOLUTIONS

# %% [markdown]
# ### Exercise 1:
# ```
# sales = [177, 201, 359, 407]
# employees = ["Parvati", "Angelo", "Serena"]
# ```

# %% [markdown]
# ### Exercise 2:
# ```
# ages = [20, 19, 21, 20, 19]
# ages.append(19)
# ages.append(20)
# ```

# %% [markdown]
# ### Exercise 3:
# ```
# sales = [1250, 2700, 3935, 1045, 2220]
# print(len(sales))
# print(sum(sales))
# print(min(sales))
# print(max(sales))
# print(sum(sales) / len(sales))
# ```
