# %% [markdown]
# # [Optional] Practice with comparisons and if statements
#
# Use these code exercises to practice working with comparisons and if statements! These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Python.

# %% [markdown]
# ## Exercise 1: Comparisons between numbers

# %% [markdown]
# ### Instructions
#
# In the code block below, you can find the variables `stock_apples` and `stock_oranges`.
#
# 1. Use a comparison operator to check whether `stock_apples` is greater than `stock_oranges` and print out the result.
# 2. Use a comparison operator to check whether `stock_apples` is two times `stock_oranges` or more and print out the result.
# 3. Use a comparison operator to check whether `stock_apples` and `stock_oranges` are equal and print out the result.
# 4. After (below) the prints corresponding to the first three tasks, assign new values of `stock_apples` to `19` and `stock_oranges` to `21`. After that repeat the prints from steps 1., 2., and 3. and compare the results.

# %%
stock_apples = 27
stock_oranges = 11

# %% [markdown]
# **Expected output:**
# ```
# 1. True
# 2. True
# 3. False
# 4. False
#    False
#    False
# ```

# %% [markdown]
# ## Exercise 2: If statements
#
# In this exercise you will learn how to check if a variable has a certain value. You can use the `if` statement to do that.

# %% [markdown]
# ### Instructions
#
# You have a variable called `profit`:
#
# 1. Use an `if` statement with the correct condition to check if `profit` is at least 1000 or larger.
# 2. if the condition is met, print out "We are going to be rich!".

# %%
profit = 1250

# %% [markdown]
# **Expected output:**
#
# 1. We are going to be rich!

# %% [markdown]
# ## Exercise 3: If and else statements
#
# You will repeat the previous exercise, this time adding what happens if the condition is not met. In addition to the `if` statement from the previous exercise, you will now also use the `else` statement.

# %% [markdown]
# ### Instructions
#
# You have a variable called `profit`:
#
# 1. Use an `if` statement with the correct condition to check if `profit` is at least 1000 or larger.
# 2. If the condition is met, print out "We are going to be rich!".
# 3. Use an `else` statement to account for all the other cases and print out "We need to work harder!" if the condition from the `if` statement is not met.

# %%
profit = 950

# %% [markdown]
# **Expected output:**
#
# 1. We need to work harder!

# %% [markdown]
# ## SOLUTIONS

# %% [markdown]
# ### Exercise 1:
# ```
# stock_apples = 27
# stock_oranges = 11
# print(stock_apples > stock_oranges)
# print(stock_apples >= 2 * stock_oranges)
# print(stock_apples == stock_oranges)
# stock_apples = 19
# stock_oranges = 21
# print(stock_apples > stock_oranges)
# print(stock_apples >= 2 * stock_oranges)
# print(stock_apples == stock_oranges)
# ```

# %% [markdown]
# ### Exercise 2:
# ```
# profit = 1000
# if profit >= 1000:
#     print("We are going to be rich!")
# ```

# %% [markdown]
# ### Exercise 3:
# ```
# profit = 950
# if profit >= 1000:
#     print("We are going to be rich!")
# else:
#     print("We need to work harder!")
# ```
