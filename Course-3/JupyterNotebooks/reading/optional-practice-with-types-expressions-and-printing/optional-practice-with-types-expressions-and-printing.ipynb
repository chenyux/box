# %% [markdown]
# # [Optional] Practice with types, expressions, and printing
#
# These code exercises allow you to build the Python skills you've seen so far in the lectures. As Andrew mentioned in the first video of this course, you should try the code yourself to understand how it works! These code blocks are optional, and you may choose to spend more or less time with them depending on your level of familiarity with Python.

# %% [markdown]
# ## Exercise 1: Math operations in Python
#
# You will begin using Python as a calculator.

# %% [markdown]
# ### Instructions
#
# 1. In the code block below, add the numbers 10 and 15. (*tip: put your calculation inside* `print()` *to display the output to the screen*)

# %%
1+2

# %% [markdown]
# 2. Divide the number 15 by the number 3

# %% [markdown]
# 3. Multiply the values 1.5 and 2.1

# %% [markdown]
# 4. See what happens when you try to add the strings "Hello" and "World".

# %% [markdown]
# **Expected output:**
#
# HelloWorld

# %% [markdown]
# ## Exercise 2: Printing

# %% [markdown]
# ### Instructions
#
# 1. In the code block below, print the text "I'm starting my Python journey!".

# %%
1+2

# %% [markdown]
# **Expected output:**
#
# I'm starting my Python journey!

# %% [markdown]
# 2. In the code block below, print the text "5+2 is " and the result of adding 5 and 2. (Tip: remember that you can separate multiple inputs with a comma.)

# %%
1+2

# %% [markdown]
# **Expected output:**
#
# 5+2 is 7

# %% [markdown]
# ## SOLUTIONS

# %% [markdown]
# ### Exercise 1:
# ```
# print(10 + 15)
#
# print(15 / 3)
#
# print(1.5 * 2.1)
#
# print("Hello" + "World")
# ```

# %% [markdown]
# ### Exercise 2:
# ```
# print("I'm starting my Python journey!")
#
# print("5+2 is", 5 + 2)
# ```
